# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
ruta_df1 = r"C:\Users\danie\OneDrive\Escritorio\DATA\dataset_final_v4l.csv"
ruta_df2 = r"C:\Users\danie\OneDrive\Escritorio\DATA\definitivo_v4l.csv"

df1 = pd.read_csv(ruta_df1)
df2 = pd.read_csv(ruta_df2)

print("df1:", df1.shape)
print("df2:", df2.shape)
# Out:
# df1: (4088, 82)
# df2: (4088, 82)

# %%
# Inspección inicial
print("DF1:")
display(df1.head())
print(df1.shape)

# Ver nombres de columnas
print("\nColumnas DF1:")
print(df1.columns)
# Out:
# DF1:
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    12207593  22795209  30000646          43      M                      1
# 1    16828280  22369507  30007565          84      M                      1
# 2    18329161  26183616  30010035          61      F                      5
# 3    14731650  28724382  30011241          82      F                      1
# 4    14475287  26952283  30014019          85      F                      1
#
#    horas_hasta_norad  etiqueta_norad_12_48  tiene_sepsis  sofa_media  ...  \
# 0                NaN                     0             0    1.416667  ...
# 1          35.433333                     1             1    9.500000  ...
# 2                NaN                     0             0    2.000000  ...
# 3                NaN                     0             1    1.833333  ...
# 4          62.031389                     0             0    3.916667  ...
#
#    fio2_max    pf_media      pf_min      pf_max  gcs_media  gcs_min  gcs_max  \
# 0     100.0   71.000000   71.000000   71.000000  15.000000       15       15
# 1     100.0  154.054054   58.000000  328.333333   4.750000        3       10
# 2      30.0  155.000000  123.333333  186.666667  11.000000       11       11
# 3      40.0  509.333333  477.500000  545.714286   9.333333        8       10
# 4      50.0  314.000000  290.000000  338.000000   8.333333        8        9
#
#    diuresis_volumen_12h  peso_kg  diuresis_ml_kg_12h
# 0                1700.0     79.0           21.518987
# 1                 685.0    106.0            6.462264
# 2                 875.0     54.0           16.203704
# 3                 795.0     85.0            9.352941
# 4                 895.0     61.2           14.624183
#
# [5 rows x 82 columns]
# (4088, 82)
#
# Columnas DF1:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_12_48',
#        'tiene_sepsis', 'sofa_media', 'sofa_min', 'sofa_max',
#        'ventilacion_invasiva_12h', 'lactato_media', 'lactato_min',
#        'lactato_max', 'creatinina_media', 'creatinina_min', 'creatinina_max',
#        'plaquetas_media', 'plaquetas_min', 'plaquetas_max',
#        'bilirrubina_media', 'bilirrubina_min', 'bilirrubina_max', 'tp_media',
#        'tp_min', 'tp_max', 'gpt_media', 'gpt_min', 'gpt_max', 'got_media',
#        'got_min', 'got_max', 'pao2_media', 'pao2_min', 'pao2_max', 'ph_media',
#        'ph_min', 'ph_max', 'leucocitos_media', 'leucocitos_min',
#        'leucocitos_max', 'paco2_media', 'paco2_min', 'paco2_max',
#        'bicarbonato_media', 'bicarbonato_min', 'bicarbonato_max',
#        'glucemia_media', 'glucemia_min', 'glucemia_max', 'hemoglobina_media',
#        'hemoglobina_min', 'hemoglobina_max', 'hr_media', 'hr_min', 'hr_max',
#        'rr_media', 'rr_min', 'rr_max', 'temp_media', 'temp_min', 'temp_max',
#        'spo2_media', 'spo2_min', 'spo2_max', 'map_media', 'map_min', 'map_max',
#        'fio2_media', 'fio2_min', 'fio2_max', 'pf_media', 'pf_min', 'pf_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_12h', 'peso_kg',
#        'diuresis_ml_kg_12h'],
#       dtype='object')

# %%
print("DF2 (clean):")
display(df2.head())
print(df2.shape)

# Ver nombres de columnas
print("\nColumnas DF2:")
print(df2.columns)
# Out:
# DF2 (clean):
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    12207593  22795209  30000646          43      M                      1
# 1    16828280  22369507  30007565          84      M                      1
# 2    18329161  26183616  30010035          61      F                      5
# 3    14731650  28724382  30011241          82      F                      1
# 4    14475287  26952283  30014019          85      F                      1
#
#    horas_hasta_norad  etiqueta_norad_12_48  tiene_sepsis  sofa_media  ...  \
# 0                NaN                     0             0    1.416667  ...
# 1          35.433333                     1             1    9.500000  ...
# 2                NaN                     0             0    2.000000  ...
# 3                NaN                     0             1    1.833333  ...
# 4          62.031389                     0             0    3.916667  ...
#
#    fio2_max    pf_media      pf_min      pf_max  gcs_media  gcs_min  gcs_max  \
# 0     100.0   71.000000   71.000000   71.000000  15.000000       15       15
# 1     100.0  154.054054   58.000000  328.333333   4.750000        3       10
# 2      30.0  155.000000  123.333333  186.666667  11.000000       11       11
# 3      40.0  509.333333  473.766667  545.714286   9.333333        8       10
# 4      50.0  314.000000  290.000000  338.000000   8.333333        8        9
#
#    diuresis_volumen_12h  peso_kg  diuresis_ml_kg_12h
# 0                1700.0     79.0           21.518987
# 1                 685.0    106.0            6.462264
# 2                 875.0     54.0           16.203704
# 3                 795.0     85.0            9.352941
# 4                 895.0     61.2           14.624183
#
# [5 rows x 82 columns]
# (4088, 82)
#
# Columnas DF2:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_12_48',
#        'tiene_sepsis', 'sofa_media', 'sofa_min', 'sofa_max',
#        'ventilacion_invasiva_12h', 'lactato_media', 'lactato_min',
#        'lactato_max', 'creatinina_media', 'creatinina_min', 'creatinina_max',
#        'plaquetas_media', 'plaquetas_min', 'plaquetas_max',
#        'bilirrubina_media', 'bilirrubina_min', 'bilirrubina_max', 'tp_media',
#        'tp_min', 'tp_max', 'gpt_media', 'gpt_min', 'gpt_max', 'got_media',
#        'got_min', 'got_max', 'pao2_media', 'pao2_min', 'pao2_max', 'ph_media',
#        'ph_min', 'ph_max', 'leucocitos_media', 'leucocitos_min',
#        'leucocitos_max', 'paco2_media', 'paco2_min', 'paco2_max',
#        'bicarbonato_media', 'bicarbonato_min', 'bicarbonato_max',
#        'glucemia_media', 'glucemia_min', 'glucemia_max', 'hemoglobina_media',
#        'hemoglobina_min', 'hemoglobina_max', 'hr_media', 'hr_min', 'hr_max',
#        'rr_media', 'rr_min', 'rr_max', 'temp_media', 'temp_min', 'temp_max',
#        'spo2_media', 'spo2_min', 'spo2_max', 'map_media', 'map_min', 'map_max',
#        'fio2_media', 'fio2_min', 'fio2_max', 'pf_media', 'pf_min', 'pf_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_12h', 'peso_kg',
#        'diuresis_ml_kg_12h'],
#       dtype='object')

# %%
df1.info() #Información general
display(df1.describe()) #Estadísticas descriptivas: cuenta, media, desviación, minimo, maximo y percentiles.
df1.isnull().sum() # Conteo de valores que no están por columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4088 entries, 0 to 4087
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   subject_id                4088 non-null   int64
#  1   hadm_id                   4088 non-null   int64
#  2   stay_id                   4088 non-null   int64
#  3   anchor_age                4088 non-null   int64
#  4   gender                    4088 non-null   object
#  5   contador_estancia_uci     4088 non-null   int64
#  6   horas_hasta_norad         747 non-null    float64
#  7   etiqueta_norad_12_48      4088 non-null   int64
#  8   tiene_sepsis              4088 non-null   int64
#  9   sofa_media                4088 non-null   float64
#  10  sofa_min                  4088 non-null   int64
#  11  sofa_max                  4088 non-null   int64
#  12  ventilacion_invasiva_12h  4088 non-null   int64
#  13  lactato_media             4088 non-null   float64
#  14  lactato_min               4088 non-null   float64
#  15  lactato_max               4088 non-null   float64
#  16  creatinina_media          4088 non-null   float64
#  17  creatinina_min            4088 non-null   float64
#  18  creatinina_max            4088 non-null   float64
#  19  plaquetas_media           4088 non-null   float64
#  20  plaquetas_min             4088 non-null   int64
#  21  plaquetas_max             4088 non-null   float64
#  22  bilirrubina_media         4088 non-null   float64
#  23  bilirrubina_min           4088 non-null   float64
#  24  bilirrubina_max           4088 non-null   float64
#  25  tp_media                  4088 non-null   float64
#  26  tp_min                    4088 non-null   float64
#  27  tp_max                    4088 non-null   float64
#  28  gpt_media                 4088 non-null   float64
#  29  gpt_min                   4088 non-null   int64
#  30  gpt_max                   4088 non-null   int64
#  31  got_media                 4088 non-null   float64
#  32  got_min                   4088 non-null   int64
#  33  got_max                   4088 non-null   int64
#  34  pao2_media                4088 non-null   float64
#  35  pao2_min                  4088 non-null   int64
#  36  pao2_max                  4088 non-null   int64
#  37  ph_media                  4088 non-null   float64
#  38  ph_min                    4088 non-null   float64
#  39  ph_max                    4088 non-null   float64
#  40  leucocitos_media          4088 non-null   float64
#  41  leucocitos_min            4088 non-null   float64
#  42  leucocitos_max            4088 non-null   float64
#  43  paco2_media               4088 non-null   float64
#  44  paco2_min                 4088 non-null   int64
#  45  paco2_max                 4088 non-null   int64
#  46  bicarbonato_media         4088 non-null   float64
#  47  bicarbonato_min           4088 non-null   float64
#  48  bicarbonato_max           4088 non-null   int64
#  49  glucemia_media            4088 non-null   float64
#  50  glucemia_min              4088 non-null   int64
#  51  glucemia_max              4088 non-null   int64
#  52  hemoglobina_media         4088 non-null   float64
#  53  hemoglobina_min           4088 non-null   float64
#  54  hemoglobina_max           4088 non-null   float64
#  55  hr_media                  4088 non-null   float64
#  56  hr_min                    4088 non-null   float64
#  57  hr_max                    4088 non-null   int64
#  58  rr_media                  4088 non-null   float64
#  59  rr_min                    4088 non-null   int64
#  60  rr_max                    4088 non-null   int64
#  61  temp_media                4088 non-null   float64
#  62  temp_min                  4088 non-null   float64
#  63  temp_max                  4088 non-null   float64
#  64  spo2_media                4088 non-null   float64
#  65  spo2_min                  4088 non-null   int64
#  66  spo2_max                  4088 non-null   int64
#  67  map_media                 4088 non-null   float64
#  68  map_min                   4088 non-null   int64
#  69  map_max                   4088 non-null   int64
#  70  fio2_media                4088 non-null   float64
#  71  fio2_min                  4088 non-null   float64
#  72  fio2_max                  4088 non-null   float64
#  73  pf_media                  4088 non-null   float64
#  74  pf_min                    4088 non-null   float64
#  75  pf_max                    4080 non-null   float64
#  76  gcs_media                 4088 non-null   float64
#  77  gcs_min                   4088 non-null   int64
#  78  gcs_max                   4088 non-null   int64
#  79  diuresis_volumen_12h      4088 non-null   float64
#  80  peso_kg                   4088 non-null   float64
#  81  diuresis_ml_kg_12h        4088 non-null   float64
# dtypes: float64(50), int64(31), object(1)
# memory usage: 2.6+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  4.088000e+03  4.088000e+03  4.088000e+03  4088.000000
# mean   1.496626e+07  2.495117e+07  3.506122e+07    60.710127
# std    2.889045e+06  2.880991e+06  2.896158e+06    16.679740
# min    1.000188e+07  2.000533e+07  3.000065e+07    18.000000
# 25%    1.246802e+07  2.243328e+07  3.256656e+07    50.000000
# 50%    1.497674e+07  2.495116e+07  3.507412e+07    62.000000
# 75%    1.739650e+07  2.740730e+07  3.759662e+07    73.000000
# max    1.999784e+07  2.999728e+07  3.999612e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_12_48  \
# count            4088.000000         747.000000           4088.000000
# mean                1.337818          67.523822              0.111546
# std                 1.061882          85.185609              0.314846
# min                 1.000000          12.006389              0.000000
# 25%                 1.000000          20.403333              0.000000
# 50%                 1.000000          36.116667              0.000000
# 75%                 1.000000          78.233333              0.000000
# max                25.000000         755.423611              1.000000
#
#        tiene_sepsis   sofa_media     sofa_min  ...     fio2_max     pf_media  \
# count   4088.000000  4088.000000  4088.000000  ...  4088.000000  4088.000000
# mean       0.328523     4.139125     2.169521  ...    68.423422   245.938421
# std        0.469733     2.607475     2.434939  ...    26.406650   181.382178
# min        0.000000     0.000000     0.000000  ...     0.950000    21.794872
# 25%        0.000000     2.121528     0.000000  ...    50.000000   123.458333
# 50%        0.000000     3.750000     1.000000  ...    60.000000   205.358974
# 75%        1.000000     5.750000     3.000000  ...   100.000000   333.052879
# max        1.000000    14.727273    14.000000  ...   400.000000  6157.894737
#
#             pf_min        pf_max    gcs_media      gcs_min      gcs_max  \
# count  4088.000000   4080.000000  4088.000000  4088.000000  4088.000000
# mean    152.400811    405.414104     8.490161     6.975049     9.918542
# std     130.640367    577.877432     3.672624     4.114327     3.896064
# min       9.166667     24.000000     3.000000     3.000000     3.000000
# 25%      72.000000    166.666667     6.000000     3.000000     7.000000
# 50%     111.000000    310.000000     8.000000     6.000000    10.000000
# 75%     198.000000    536.785714    10.616667    10.000000    14.000000
# max    3894.736842  29750.000000    15.000000    15.000000    15.000000
#
#        diuresis_volumen_12h      peso_kg  diuresis_ml_kg_12h
# count           4088.000000  4088.000000         4088.000000
# mean             929.066634    84.365494           13.028367
# std              804.354455    25.839549           47.210734
# min            -1575.000000     1.000000          -22.826087
# 25%              405.000000    67.300000            4.852541
# 50%              714.500000    80.500000            8.779316
# 75%             1210.000000    97.200000           15.441176
# max            13575.000000   277.000000         2460.000000
#
# [8 rows x 81 columns]
# subject_id              0
# hadm_id                 0
# stay_id                 0
# anchor_age              0
# gender                  0
#                        ..
# gcs_min                 0
# gcs_max                 0
# diuresis_volumen_12h    0
# peso_kg                 0
# diuresis_ml_kg_12h      0
# Length: 82, dtype: int64

# %%
df2.info()
display(df2.describe()) 
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4088 entries, 0 to 4087
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   subject_id                4088 non-null   int64
#  1   hadm_id                   4088 non-null   int64
#  2   stay_id                   4088 non-null   int64
#  3   anchor_age                4088 non-null   int64
#  4   gender                    4088 non-null   object
#  5   contador_estancia_uci     4088 non-null   int64
#  6   horas_hasta_norad         747 non-null    float64
#  7   etiqueta_norad_12_48      4088 non-null   int64
#  8   tiene_sepsis              4088 non-null   int64
#  9   sofa_media                4088 non-null   float64
#  10  sofa_min                  4088 non-null   int64
#  11  sofa_max                  4088 non-null   int64
#  12  ventilacion_invasiva_12h  4088 non-null   int64
#  13  lactato_media             4088 non-null   float64
#  14  lactato_min               4088 non-null   float64
#  15  lactato_max               4088 non-null   float64
#  16  creatinina_media          4088 non-null   float64
#  17  creatinina_min            4088 non-null   float64
#  18  creatinina_max            4088 non-null   float64
#  19  plaquetas_media           4088 non-null   float64
#  20  plaquetas_min             4088 non-null   float64
#  21  plaquetas_max             4088 non-null   float64
#  22  bilirrubina_media         4088 non-null   float64
#  23  bilirrubina_min           4088 non-null   float64
#  24  bilirrubina_max           4088 non-null   float64
#  25  tp_media                  4088 non-null   float64
#  26  tp_min                    4088 non-null   float64
#  27  tp_max                    4088 non-null   float64
#  28  gpt_media                 4088 non-null   float64
#  29  gpt_min                   4088 non-null   float64
#  30  gpt_max                   4088 non-null   float64
#  31  got_media                 4088 non-null   float64
#  32  got_min                   4088 non-null   float64
#  33  got_max                   4088 non-null   float64
#  34  pao2_media                4088 non-null   float64
#  35  pao2_min                  4088 non-null   float64
#  36  pao2_max                  4088 non-null   float64
#  37  ph_media                  4088 non-null   float64
#  38  ph_min                    4088 non-null   float64
#  39  ph_max                    4088 non-null   float64
#  40  leucocitos_media          4088 non-null   float64
#  41  leucocitos_min            4088 non-null   float64
#  42  leucocitos_max            4088 non-null   float64
#  43  paco2_media               4088 non-null   float64
#  44  paco2_min                 4088 non-null   float64
#  45  paco2_max                 4088 non-null   float64
#  46  bicarbonato_media         4088 non-null   float64
#  47  bicarbonato_min           4088 non-null   float64
#  48  bicarbonato_max           4088 non-null   float64
#  49  glucemia_media            4088 non-null   float64
#  50  glucemia_min              4088 non-null   float64
#  51  glucemia_max              4088 non-null   float64
#  52  hemoglobina_media         4088 non-null   float64
#  53  hemoglobina_min           4088 non-null   float64
#  54  hemoglobina_max           4088 non-null   float64
#  55  hr_media                  4088 non-null   float64
#  56  hr_min                    4088 non-null   float64
#  57  hr_max                    4088 non-null   float64
#  58  rr_media                  4088 non-null   float64
#  59  rr_min                    4088 non-null   float64
#  60  rr_max                    4088 non-null   float64
#  61  temp_media                4088 non-null   float64
#  62  temp_min                  4088 non-null   float64
#  63  temp_max                  4088 non-null   float64
#  64  spo2_media                4088 non-null   float64
#  65  spo2_min                  4088 non-null   float64
#  66  spo2_max                  4088 non-null   float64
#  67  map_media                 4088 non-null   float64
#  68  map_min                   4088 non-null   float64
#  69  map_max                   4088 non-null   float64
#  70  fio2_media                4088 non-null   float64
#  71  fio2_min                  4088 non-null   float64
#  72  fio2_max                  4088 non-null   float64
#  73  pf_media                  4088 non-null   float64
#  74  pf_min                    4088 non-null   float64
#  75  pf_max                    4080 non-null   float64
#  76  gcs_media                 4088 non-null   float64
#  77  gcs_min                   4088 non-null   int64
#  78  gcs_max                   4088 non-null   int64
#  79  diuresis_volumen_12h      4088 non-null   float64
#  80  peso_kg                   4088 non-null   float64
#  81  diuresis_ml_kg_12h        4088 non-null   float64
# dtypes: float64(69), int64(12), object(1)
# memory usage: 2.6+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  4.088000e+03  4.088000e+03  4.088000e+03  4088.000000
# mean   1.496626e+07  2.495117e+07  3.506122e+07    60.710127
# std    2.889045e+06  2.880991e+06  2.896158e+06    16.679740
# min    1.000188e+07  2.000533e+07  3.000065e+07    18.000000
# 25%    1.246802e+07  2.243328e+07  3.256656e+07    50.000000
# 50%    1.497674e+07  2.495116e+07  3.507412e+07    62.000000
# 75%    1.739650e+07  2.740730e+07  3.759662e+07    73.000000
# max    1.999784e+07  2.999728e+07  3.999612e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_12_48  \
# count            4088.000000         747.000000           4088.000000
# mean                1.337818          67.523822              0.111546
# std                 1.061882          85.185609              0.314846
# min                 1.000000          12.006389              0.000000
# 25%                 1.000000          20.403333              0.000000
# 50%                 1.000000          36.116667              0.000000
# 75%                 1.000000          78.233333              0.000000
# max                25.000000         755.423611              1.000000
#
#        tiene_sepsis   sofa_media     sofa_min  ...     fio2_max     pf_media  \
# count   4088.000000  4088.000000  4088.000000  ...  4088.000000  4088.000000
# mean       0.328523     4.139125     2.169521  ...    68.316781   242.437184
# std        0.469733     2.607475     2.434939  ...    25.441791   147.806429
# min        0.000000     0.000000     0.000000  ...    30.000000    49.577087
# 25%        0.000000     2.121528     0.000000  ...    50.000000   123.458333
# 50%        0.000000     3.750000     1.000000  ...    60.000000   205.358974
# 75%        1.000000     5.750000     3.000000  ...   100.000000   333.052879
# max        1.000000    14.727273    14.000000  ...   100.000000   642.391176
#
#             pf_min       pf_max    gcs_media      gcs_min      gcs_max  \
# count  4088.000000  4080.000000  4088.000000  4088.000000  4088.000000
# mean    149.665667   390.775846     8.490161     6.975049     9.918542
# std     108.559744   286.997886     3.672624     4.114327     3.896064
# min      30.000000    58.575000     3.000000     3.000000     3.000000
# 25%      72.000000   166.666667     6.000000     3.000000     7.000000
# 50%     111.000000   310.000000     8.000000     6.000000    10.000000
# 75%     198.000000   536.785714    10.616667    10.000000    14.000000
# max     473.766667  1203.757143    15.000000    15.000000    15.000000
#
#        diuresis_volumen_12h      peso_kg  diuresis_ml_kg_12h
# count           4088.000000  4088.000000         4088.000000
# mean             913.025783    83.872099           11.553476
# std              718.812783    23.036741            9.445756
# min               25.000000    44.774000            0.327193
# 25%              405.000000    67.300000            4.852541
# 50%              714.500000    80.500000            8.779316
# 75%             1210.000000    97.200000           15.441176
# max             3235.000000   148.926000           41.733365
#
# [8 rows x 81 columns]
# subject_id              0
# hadm_id                 0
# stay_id                 0
# anchor_age              0
# gender                  0
#                        ..
# gcs_min                 0
# gcs_max                 0
# diuresis_volumen_12h    0
# peso_kg                 0
# diuresis_ml_kg_12h      0
# Length: 82, dtype: int64

# %%
# Cada fila representa una estancia en UCI
n_pacientes = df1['subject_id'].nunique()
n_admisiones = df1['hadm_id'].nunique()
n_estancias = df1['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df1) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3918
# Admisiones únicas (hadm_id):   4048
# Estancias únicas (stay_id):    4088
# Ratio estancias/paciente:      1.043389484430832

# %%
n_pacientes = df2['subject_id'].nunique()
n_admisiones = df2['hadm_id'].nunique()
n_estancias = df2['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df2) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3918
# Admisiones únicas (hadm_id):   4048
# Estancias únicas (stay_id):    4088
# Ratio estancias/paciente:      1.043389484430832

# %%
# describe() sobre variables numéricas. Excluimos identificadores y la etiqueta
# para mostrar solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df1.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_12_48', 'horas_hasta_norad']]

df1[cols_descriptivo].describe().T
# Out:
#                         count        mean         std          min  \
# anchor_age             4088.0   60.710127   16.679740    18.000000
# contador_estancia_uci  4088.0    1.337818    1.061882     1.000000
# tiene_sepsis           4088.0    0.328523    0.469733     0.000000
# sofa_media             4088.0    4.139125    2.607475     0.000000
# sofa_min               4088.0    2.169521    2.434939     0.000000
# ...                       ...         ...         ...          ...
# gcs_min                4088.0    6.975049    4.114327     3.000000
# gcs_max                4088.0    9.918542    3.896064     3.000000
# diuresis_volumen_12h   4088.0  929.066634  804.354455 -1575.000000
# peso_kg                4088.0   84.365494   25.839549     1.000000
# diuresis_ml_kg_12h     4088.0   13.028367   47.210734   -22.826087
#
#                               25%         50%          75%           max
# anchor_age              50.000000   62.000000    73.000000     91.000000
# contador_estancia_uci    1.000000    1.000000     1.000000     25.000000
# tiene_sepsis             0.000000    0.000000     1.000000      1.000000
# sofa_media               2.121528    3.750000     5.750000     14.727273
# sofa_min                 0.000000    1.000000     3.000000     14.000000
# ...                           ...         ...          ...           ...
# gcs_min                  3.000000    6.000000    10.000000     15.000000
# gcs_max                  7.000000   10.000000    14.000000     15.000000
# diuresis_volumen_12h   405.000000  714.500000  1210.000000  13575.000000
# peso_kg                 67.300000   80.500000    97.200000    277.000000
# diuresis_ml_kg_12h       4.852541    8.779316    15.441176   2460.000000
#
# [76 rows x 8 columns]

# %%
# describe() sobre variables numéricas. 
# solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df2.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_12_48', 'horas_hasta_norad']]

df2[cols_descriptivo].describe().T
# Out:
#                         count        mean         std        min         25%  \
# anchor_age             4088.0   60.710127   16.679740  18.000000   50.000000
# contador_estancia_uci  4088.0    1.337818    1.061882   1.000000    1.000000
# tiene_sepsis           4088.0    0.328523    0.469733   0.000000    0.000000
# sofa_media             4088.0    4.139125    2.607475   0.000000    2.121528
# sofa_min               4088.0    2.169521    2.434939   0.000000    0.000000
# ...                       ...         ...         ...        ...         ...
# gcs_min                4088.0    6.975049    4.114327   3.000000    3.000000
# gcs_max                4088.0    9.918542    3.896064   3.000000    7.000000
# diuresis_volumen_12h   4088.0  913.025783  718.812783  25.000000  405.000000
# peso_kg                4088.0   83.872099   23.036741  44.774000   67.300000
# diuresis_ml_kg_12h     4088.0   11.553476    9.445756   0.327193    4.852541
#
#                               50%          75%          max
# anchor_age              62.000000    73.000000    91.000000
# contador_estancia_uci    1.000000     1.000000    25.000000
# tiene_sepsis             0.000000     1.000000     1.000000
# sofa_media               3.750000     5.750000    14.727273
# sofa_min                 1.000000     3.000000    14.000000
# ...                           ...          ...          ...
# gcs_min                  6.000000    10.000000    15.000000
# gcs_max                 10.000000    14.000000    15.000000
# diuresis_volumen_12h   714.500000  1210.000000  3235.000000
# peso_kg                 80.500000    97.200000   148.926000
# diuresis_ml_kg_12h       8.779316    15.441176    41.733365
#
# [76 rows x 8 columns]

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_12h']

resumen_por_clase = df1.groupby('etiqueta_norad_12_48')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_12_48                0           1
# anchor_age         mean     60.582324   61.728070
#                    median   62.000000   63.000000
# lactato_max        mean      2.752395    3.147588
#                    median    1.900000    2.300000
# creatinina_max     mean      1.561894    1.783991
#                    median    1.100000    1.300000
# map_min            mean     62.568007   59.760965
#                    median   64.000000   61.000000
# hr_max             mean    105.042676  106.973684
#                    median  104.000000  107.000000
# gcs_min            mean      6.937775    7.271930
#                    median    6.000000    6.000000
# ph_min             mean      7.326101    7.307632
#                    median    7.340000    7.320000
# diuresis_ml_kg_12h mean     13.268167   11.118383
#                    median    8.853913    7.726142

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_12h']

resumen_por_clase = df2.groupby('etiqueta_norad_12_48')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_12_48                0           1
# anchor_age         mean     60.582324   61.728070
#                    median   62.000000   63.000000
# lactato_max        mean      2.695843    3.073026
#                    median    1.900000    2.300000
# creatinina_max     mean      1.517771    1.743829
#                    median    1.100000    1.300000
# map_min            mean     62.414097   59.410088
#                    median   64.000000   61.000000
# hr_max             mean    104.864262  106.861842
#                    median  104.000000  107.000000
# gcs_min            mean      6.937775    7.271930
#                    median    6.000000    6.000000
# ph_min             mean      7.327070    7.309211
#                    median    7.340000    7.320000
# diuresis_ml_kg_12h mean     11.643572   10.835874
#                    median    8.853913    7.726142

# %%
#VARIABLES CON VARIANZA MUY BAJA

excluir = ['subject_id', 'hadm_id', 'stay_id',
           'horas_hasta_norad', 'etiqueta_norad_12_48']
num_cols = [c for c in df2.select_dtypes(include=[np.number]).columns
            if c not in excluir]

# Calculamos el coeficiente de variación (std/|mean|) para comparar entre escalas
resumen_var = pd.DataFrame({
    'std': df2[num_cols].std(),
    'mean': df2[num_cols].mean(),
})
resumen_var['cv'] = resumen_var['std'] / resumen_var['mean']
resumen_var.sort_values('cv').head(20)
# Out:
#                          std        mean        cv
# ph_max              0.070989    7.398060  0.009596
# ph_media            0.075982    7.362878  0.010320
# spo2_max            1.041561   99.507339  0.010467
# ph_min              0.099077    7.325078  0.013526
# temp_media          0.677092   36.909545  0.018345
# temp_max            0.779060   37.379550  0.020842
# spo2_media          2.234570   97.442778  0.022932
# temp_min            0.835928   36.438763  0.022941
# spo2_min            5.128785   93.387476  0.054919
# map_media          11.854189   79.807967  0.148534
# hemoglobina_max     2.183966   10.876639  0.200794
# hr_media           18.012873   89.479129  0.201308
# hr_max             21.286705  105.087084  0.202563
# bicarbonato_max     4.780181   23.329012  0.204903
# hemoglobina_media   2.162132   10.512208  0.205678
# bicarbonato_media   4.823674   22.566652  0.213752
# rr_media            4.429137   20.221562  0.219030
# paco2_media         9.348882   42.515036  0.219896
# hemoglobina_min     2.261855   10.152886  0.222780
# hr_min             17.321574   76.983415  0.225004

# %% [markdown]
# ### Análisis de la variable objetivo

# %%
# Conteo y porcentaje por clase
conteo = df2['etiqueta_norad_12_48'].value_counts()
prevalencia = df2['etiqueta_norad_12_48'].value_counts(normalize=True)

resumen_clases = pd.DataFrame({
    'n': conteo,
    'porcentaje': (100*prevalencia).round(2)
})
resumen_clases.index = ['Negativos (no norad en 12-48h)', 'Positivos (norad en 12-48h)']
print(resumen_clases)
# Out:
#                                    n  porcentaje
# Negativos (no norad en 12-48h)  3632       88.85
# Positivos (norad en 12-48h)      456       11.15

# %%
#¿Cuándo se inicia la noradrenalina dentro de la ventana 12-48h?
positivos = df2[df2['etiqueta_norad_12_48'] == 1]['horas_hasta_norad']

print(f"Estadísticos de horas_hasta_norad en positivos (n={len(positivos)}):")
print(positivos.describe().round(2).to_string())
# Out:
# Estadísticos de horas_hasta_norad en positivos (n=456):
# count    456.00
# mean      24.71
# std       10.00
# min       12.01
# 25%       16.21
# 50%       22.34
# 75%       31.30
# max       47.75

# %%
# Histograma de horas_hasta_norad en positivos
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(positivos, bins=np.arange(12, 49, 2), color='#ff7f0e', alpha=0.8)
ax.axvline(positivos.median(), color='navy', linestyle='--',
           linewidth=2, label=f'Mediana = {positivos.median():.1f} h')
ax.axvline(positivos.mean(), color='darkred', linestyle=':',
           linewidth=2, label=f'Media = {positivos.mean():.1f} h')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Distribución temporal del evento en la clase positiva (n={len(positivos)})')
ax.set_xticks(np.arange(12, 49, 4))
ax.legend()
plt.tight_layout()
plt.show()

# %%
# ¿Cómo se componen los negativos?
neg = df2[df2['etiqueta_norad_12_48'] == 0]

neg_norad_tardia = neg[neg['horas_hasta_norad'].notna()]
neg_sin_norad   = neg[neg['horas_hasta_norad'].isna()]

print(f"Total de negativos: {len(neg)}")
print(f"  - Recibieron noradrenalina tras las 48 h ({neg_norad_tardia['horas_hasta_norad'].min()}h a "
      f"{neg_norad_tardia['horas_hasta_norad'].max()}h): {len(neg_norad_tardia)}")
print(f"  - No recibieron noradrenalina durante la estancia:              {len(neg_sin_norad)}")
# Out:
# Total de negativos: 3632
#   - Recibieron noradrenalina tras las 48 h (48.05h a 755.4236111111111h): 291
#   - No recibieron noradrenalina durante la estancia:              3341

# %%
# Para los negativos que sí recibieron norad (pero tardíamente), ver cuándo la iniciaron
fig, ax = plt.subplots(figsize=(10, 5))
datos = neg_norad_tardia['horas_hasta_norad']
# Limitar el eje x por legibilidad (hay alguna estancia muy larga)
datos_mostrar = datos[datos <= 200]
ax.hist(datos_mostrar, bins=40, color='#1f77b4', alpha=0.7)
ax.axvline(48, color='red', linestyle='--', linewidth=2,
           label='Corte 48 h (límite de la ventana)')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Negativos con noradrenalina tardía')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Identificar pacientes que aparecen con etiqueta positiva en una estancia
por_paciente = df2.groupby('subject_id')['etiqueta_norad_12_48'].agg(['sum', 'count'])  #nos quedamos con los unos y ceros de cada "montón" y nos quedamos con la suma y counteo
pacientes_mixtos = por_paciente[(por_paciente['sum'] > 0) &
                                (por_paciente['sum'] < por_paciente['count'])] #al menios una estancia positiva y una negativa (suma tiene que dar uno y count 2 o más)

print(f"Pacientes con etiqueta mixta entre sus estancias: {len(pacientes_mixtos)}")
print(f"  (positivo en al menos una estancia, negativo en al menos otra)\n")

if len(pacientes_mixtos) > 0:
    print("Desglose:")
    print(pacientes_mixtos.head(10).to_string())
# Out:
# Pacientes con etiqueta mixta entre sus estancias: 28
#   (positivo en al menos una estancia, negativo en al menos otra)
#
# Desglose:
#             sum  count
# subject_id
# 10624280      1      3
# 10819468      1      2
# 10862862      1      2
# 10882916      1      2
# 10912090      1      2
# 11018073      1      3
# 11281568      1      4
# 11326660      1      2
# 11327015      1      2
# 11577197      1      2

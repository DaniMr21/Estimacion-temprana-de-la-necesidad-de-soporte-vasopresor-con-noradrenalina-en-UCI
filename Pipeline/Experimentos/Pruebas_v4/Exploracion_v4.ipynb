# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
ruta_df1 = r"C:\Users\danie\OneDrive\Escritorio\DATA\dataset_final_v4.csv"
ruta_df2 = r"C:\Users\danie\OneDrive\Escritorio\DATA\definitivo_v4.csv"

df1 = pd.read_csv(ruta_df1)
df2 = pd.read_csv(ruta_df2)

print("df1:", df1.shape)
print("df2:", df2.shape)
# Out:
# df1: (3282, 82)
# df2: (3282, 82)

# %%
# Inspección inicial
print("DF1:")
display(df1.head())
print(df1.shape)

# Ver nombres de columnas
print("\nColumnas DF1:")
print(df1.columns)
# Out:
# DF1:
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    16828280  22369507  30007565          84      M                      1
# 1    12851972  24518431  30010930          91      F                      1
# 2    14731650  28724382  30011241          82      F                      1
# 3    14475287  26952283  30014019          85      F                      1
# 4    11638303  25053659  30019367          42      F                      1
#
#    horas_hasta_norad  etiqueta_norad_6_24  tiene_sepsis  sofa_media  ...  \
# 0          35.433333                    0             1    9.000000  ...
# 1                NaN                    0             0    3.750000  ...
# 2                NaN                    0             1    1.666667  ...
# 3          62.031389                    0             0    2.833333  ...
# 4          49.147778                    0             1    6.833333  ...
#
#    fio2_max    pf_media      pf_min      pf_max  gcs_media  gcs_min  gcs_max  \
# 0      70.0  108.750000   82.857143  145.000000        3.0        3        3
# 1      40.0  400.000000   80.000000  962.500000        7.0        7        7
# 2      40.0  477.500000  477.500000  477.500000        9.0        8       10
# 3      50.0  290.000000  290.000000  290.000000        8.0        8        8
# 4     100.0   79.090909   58.000000   96.666667        3.0        3        3
#
#    diuresis_volumen_6h  peso_kg  diuresis_ml_kg_6h
# 0                  295    106.0           2.783019
# 1                  550     53.5          10.280374
# 2                  430     85.0           5.058824
# 3                   45     61.2           0.735294
# 4                  385     84.4           4.561611
#
# [5 rows x 82 columns]
# (3282, 82)
#
# Columnas DF1:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_6_24',
#        'tiene_sepsis', 'sofa_media', 'sofa_min', 'sofa_max',
#        'ventilacion_invasiva_6h', 'lactato_media', 'lactato_min',
#        'lactato_max', 'creatinina_media', 'creatinina_min', 'creatinina_max',
#        'plaquetas_media', 'plaquetas_min', 'plaquetas_max',
#        'bilirrubina_media', 'bilirrubina_min', 'bilirrubina_max', 'tp_media',
#        'tp_min', 'tp_max', 'gpt_media', 'gpt_min', 'gpt_max', 'got_media',
#        'got_min', 'got_max', 'pao2_media', 'pao2_min', 'pao2_max', 'ph_media',
#        'ph_min', 'ph_max', 'leucocitos_media', 'leucocitos_min',
#        'leucocitos_max', 'paco2_media', 'paco2_min', 'paco2_max',
#        'bicarbonato_media', 'bicarbonato_min', 'bicarbonato_max',
#        'glucemia_media', 'glucemia_min', 'glucemia_max', 'hemoglobina_media',
#        'hemoglobina_min', 'hemoglobina_max', 'hr_media', 'hr_min', 'hr_max',
#        'rr_media', 'rr_min', 'rr_max', 'temp_media', 'temp_min', 'temp_max',
#        'spo2_media', 'spo2_min', 'spo2_max', 'map_media', 'map_min', 'map_max',
#        'fio2_media', 'fio2_min', 'fio2_max', 'pf_media', 'pf_min', 'pf_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_6h', 'peso_kg',
#        'diuresis_ml_kg_6h'],
#       dtype='object')

# %%
print("DF2 (clean):")
display(df2.head())
print(df2.shape)

# Ver nombres de columnas
print("\nColumnas DF2:")
print(df2.columns)
# Out:
# DF2 (clean):
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    16828280  22369507  30007565          84      M                      1
# 1    12851972  24518431  30010930          91      F                      1
# 2    14731650  28724382  30011241          82      F                      1
# 3    14475287  26952283  30014019          85      F                      1
# 4    11638303  25053659  30019367          42      F                      1
#
#    horas_hasta_norad  etiqueta_norad_6_24  tiene_sepsis  sofa_media  ...  \
# 0          35.433333                    0             1    9.000000  ...
# 1                NaN                    0             0    3.750000  ...
# 2                NaN                    0             1    1.666667  ...
# 3          62.031389                    0             0    2.833333  ...
# 4          49.147778                    0             1    6.833333  ...
#
#    fio2_max    pf_media      pf_min      pf_max  gcs_media  gcs_min  gcs_max  \
# 0      70.0  108.750000   82.857143  145.000000        3.0        3        3
# 1      40.0  400.000000   80.000000  962.500000        7.0        7        7
# 2      40.0  477.500000  477.500000  477.500000        9.0        8       10
# 3      50.0  290.000000  290.000000  290.000000        8.0        8        8
# 4     100.0   79.090909   58.000000   96.666667        3.0        3        3
#
#    diuresis_volumen_6h  peso_kg  diuresis_ml_kg_6h
# 0                295.0    106.0           2.783019
# 1                550.0     53.5          10.280374
# 2                430.0     85.0           5.058824
# 3                 45.0     61.2           0.735294
# 4                385.0     84.4           4.561611
#
# [5 rows x 82 columns]
# (3282, 82)
#
# Columnas DF2:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_6_24',
#        'tiene_sepsis', 'sofa_media', 'sofa_min', 'sofa_max',
#        'ventilacion_invasiva_6h', 'lactato_media', 'lactato_min',
#        'lactato_max', 'creatinina_media', 'creatinina_min', 'creatinina_max',
#        'plaquetas_media', 'plaquetas_min', 'plaquetas_max',
#        'bilirrubina_media', 'bilirrubina_min', 'bilirrubina_max', 'tp_media',
#        'tp_min', 'tp_max', 'gpt_media', 'gpt_min', 'gpt_max', 'got_media',
#        'got_min', 'got_max', 'pao2_media', 'pao2_min', 'pao2_max', 'ph_media',
#        'ph_min', 'ph_max', 'leucocitos_media', 'leucocitos_min',
#        'leucocitos_max', 'paco2_media', 'paco2_min', 'paco2_max',
#        'bicarbonato_media', 'bicarbonato_min', 'bicarbonato_max',
#        'glucemia_media', 'glucemia_min', 'glucemia_max', 'hemoglobina_media',
#        'hemoglobina_min', 'hemoglobina_max', 'hr_media', 'hr_min', 'hr_max',
#        'rr_media', 'rr_min', 'rr_max', 'temp_media', 'temp_min', 'temp_max',
#        'spo2_media', 'spo2_min', 'spo2_max', 'map_media', 'map_min', 'map_max',
#        'fio2_media', 'fio2_min', 'fio2_max', 'pf_media', 'pf_min', 'pf_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_6h', 'peso_kg',
#        'diuresis_ml_kg_6h'],
#       dtype='object')

# %%
df1.info() #Información general
display(df1.describe()) #Estadísticas descriptivas: cuenta, media, desviación, minimo, maximo y percentiles.
df1.isnull().sum() # Conteo de valores que no están por columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Data columns (total 82 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subject_id               3282 non-null   int64
#  1   hadm_id                  3282 non-null   int64
#  2   stay_id                  3282 non-null   int64
#  3   anchor_age               3282 non-null   int64
#  4   gender                   3282 non-null   object
#  5   contador_estancia_uci    3282 non-null   int64
#  6   horas_hasta_norad        626 non-null    float64
#  7   etiqueta_norad_6_24      3282 non-null   int64
#  8   tiene_sepsis             3282 non-null   int64
#  9   sofa_media               3282 non-null   float64
#  10  sofa_min                 3282 non-null   int64
#  11  sofa_max                 3282 non-null   int64
#  12  ventilacion_invasiva_6h  3282 non-null   int64
#  13  lactato_media            3282 non-null   float64
#  14  lactato_min              3282 non-null   float64
#  15  lactato_max              3282 non-null   float64
#  16  creatinina_media         3282 non-null   float64
#  17  creatinina_min           3282 non-null   float64
#  18  creatinina_max           3282 non-null   float64
#  19  plaquetas_media          3282 non-null   float64
#  20  plaquetas_min            3282 non-null   int64
#  21  plaquetas_max            3282 non-null   float64
#  22  bilirrubina_media        3282 non-null   float64
#  23  bilirrubina_min          3282 non-null   float64
#  24  bilirrubina_max          3282 non-null   float64
#  25  tp_media                 3282 non-null   float64
#  26  tp_min                   3282 non-null   float64
#  27  tp_max                   3282 non-null   float64
#  28  gpt_media                3282 non-null   float64
#  29  gpt_min                  3282 non-null   int64
#  30  gpt_max                  3282 non-null   int64
#  31  got_media                3282 non-null   float64
#  32  got_min                  3282 non-null   int64
#  33  got_max                  3282 non-null   int64
#  34  pao2_media               3282 non-null   float64
#  35  pao2_min                 3282 non-null   int64
#  36  pao2_max                 3282 non-null   int64
#  37  ph_media                 3282 non-null   float64
#  38  ph_min                   3282 non-null   float64
#  39  ph_max                   3282 non-null   float64
#  40  leucocitos_media         3282 non-null   float64
#  41  leucocitos_min           3282 non-null   float64
#  42  leucocitos_max           3282 non-null   float64
#  43  paco2_media              3282 non-null   float64
#  44  paco2_min                3282 non-null   int64
#  45  paco2_max                3282 non-null   int64
#  46  bicarbonato_media        3282 non-null   float64
#  47  bicarbonato_min          3282 non-null   float64
#  48  bicarbonato_max          3282 non-null   int64
#  49  glucemia_media           3282 non-null   float64
#  50  glucemia_min             3282 non-null   int64
#  51  glucemia_max             3282 non-null   int64
#  52  hemoglobina_media        3282 non-null   float64
#  53  hemoglobina_min          3282 non-null   float64
#  54  hemoglobina_max          3282 non-null   float64
#  55  hr_media                 3282 non-null   float64
#  56  hr_min                   3282 non-null   float64
#  57  hr_max                   3282 non-null   int64
#  58  rr_media                 3282 non-null   float64
#  59  rr_min                   3282 non-null   int64
#  60  rr_max                   3282 non-null   int64
#  61  temp_media               3282 non-null   float64
#  62  temp_min                 3282 non-null   float64
#  63  temp_max                 3282 non-null   float64
#  64  spo2_media               3282 non-null   float64
#  65  spo2_min                 3282 non-null   int64
#  66  spo2_max                 3282 non-null   int64
#  67  map_media                3282 non-null   float64
#  68  map_min                  3282 non-null   int64
#  69  map_max                  3282 non-null   int64
#  70  fio2_media               3282 non-null   float64
#  71  fio2_min                 3282 non-null   float64
#  72  fio2_max                 3282 non-null   float64
#  73  pf_media                 3282 non-null   float64
#  74  pf_min                   3282 non-null   float64
#  75  pf_max                   3281 non-null   float64
#  76  gcs_media                3282 non-null   float64
#  77  gcs_min                  3282 non-null   int64
#  78  gcs_max                  3282 non-null   int64
#  79  diuresis_volumen_6h      3282 non-null   int64
#  80  peso_kg                  3282 non-null   float64
#  81  diuresis_ml_kg_6h        3282 non-null   float64
# dtypes: float64(49), int64(32), object(1)
# memory usage: 2.1+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  3.282000e+03  3.282000e+03  3.282000e+03  3282.000000
# mean   1.493782e+07  2.497623e+07  3.501363e+07    60.194089
# std    2.900946e+06  2.884124e+06  2.902228e+06    16.700687
# min    1.000188e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.239214e+07  2.243426e+07  3.250127e+07    50.000000
# 50%    1.491950e+07  2.497038e+07  3.504276e+07    62.000000
# 75%    1.739674e+07  2.741674e+07  3.755705e+07    73.000000
# max    1.999784e+07  2.999939e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_6_24  \
# count            3282.000000         626.000000          3282.000000
# mean                1.417124          50.244283             0.102986
# std                 1.400566          79.948621             0.303987
# min                 1.000000           6.062222             0.000000
# 25%                 1.000000          10.483750             0.000000
# 50%                 1.000000          21.678194             0.000000
# 75%                 1.000000          51.207500             0.000000
# max                36.000000         755.423611             1.000000
#
#        tiene_sepsis   sofa_media     sofa_min  ...     fio2_max     pf_media  \
# count   3282.000000  3282.000000  3282.000000  ...  3282.000000  3282.000000
# mean       0.302559     3.636718     2.237965  ...    65.525579   249.607770
# std        0.459436     2.508340     2.464447  ...    25.901101   203.329449
# min        0.000000     0.000000     0.000000  ...     0.950000    18.000000
# 25%        0.000000     1.666667     0.000000  ...    50.000000   112.045977
# 50%        0.000000     3.183333     1.000000  ...    50.000000   199.000000
# 75%        1.000000     5.000000     4.000000  ...   100.000000   341.138021
# max        1.000000    14.833333    14.000000  ...   400.000000  6157.894737
#
#             pf_min        pf_max    gcs_media      gcs_min      gcs_max  \
# count  3282.000000   3281.000000  3282.000000  3282.000000  3282.000000
# mean    182.825392    361.462709     8.026879     7.205363     8.816271
# std     158.426219    605.382386     3.827090     4.099404     4.014383
# min      14.000000     18.000000     3.000000     3.000000     3.000000
# 25%      78.000000    132.500000     5.000000     3.000000     6.000000
# 50%     130.000000    260.000000     7.500000     7.000000     9.000000
# 75%     249.583333    480.000000    10.000000    10.000000    11.000000
# max    3894.736842  29750.000000    15.000000    15.000000    15.000000
#
#        diuresis_volumen_6h      peso_kg  diuresis_ml_kg_6h
# count          3282.000000  3282.000000        3282.000000
# mean            526.233394    83.624296           8.145844
# std             482.470325    24.949103          39.434762
# min               0.000000     1.000000           0.000000
# 25%             210.000000    67.300000           2.436761
# 50%             389.000000    80.300000           4.859127
# 75%             685.000000    96.000000           8.636364
# max            5200.000000   272.000000        1920.000000
#
# [8 rows x 81 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_6h    0
# peso_kg                0
# diuresis_ml_kg_6h      0
# Length: 82, dtype: int64

# %%
df2.info()
display(df2.describe()) 
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Data columns (total 82 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subject_id               3282 non-null   int64
#  1   hadm_id                  3282 non-null   int64
#  2   stay_id                  3282 non-null   int64
#  3   anchor_age               3282 non-null   int64
#  4   gender                   3282 non-null   object
#  5   contador_estancia_uci    3282 non-null   int64
#  6   horas_hasta_norad        626 non-null    float64
#  7   etiqueta_norad_6_24      3282 non-null   int64
#  8   tiene_sepsis             3282 non-null   int64
#  9   sofa_media               3282 non-null   float64
#  10  sofa_min                 3282 non-null   int64
#  11  sofa_max                 3282 non-null   int64
#  12  ventilacion_invasiva_6h  3282 non-null   int64
#  13  lactato_media            3282 non-null   float64
#  14  lactato_min              3282 non-null   float64
#  15  lactato_max              3282 non-null   float64
#  16  creatinina_media         3282 non-null   float64
#  17  creatinina_min           3282 non-null   float64
#  18  creatinina_max           3282 non-null   float64
#  19  plaquetas_media          3282 non-null   float64
#  20  plaquetas_min            3282 non-null   float64
#  21  plaquetas_max            3282 non-null   float64
#  22  bilirrubina_media        3282 non-null   float64
#  23  bilirrubina_min          3282 non-null   float64
#  24  bilirrubina_max          3282 non-null   float64
#  25  tp_media                 3282 non-null   float64
#  26  tp_min                   3282 non-null   float64
#  27  tp_max                   3282 non-null   float64
#  28  gpt_media                3282 non-null   float64
#  29  gpt_min                  3282 non-null   float64
#  30  gpt_max                  3282 non-null   float64
#  31  got_media                3282 non-null   float64
#  32  got_min                  3282 non-null   float64
#  33  got_max                  3282 non-null   float64
#  34  pao2_media               3282 non-null   float64
#  35  pao2_min                 3282 non-null   float64
#  36  pao2_max                 3282 non-null   float64
#  37  ph_media                 3282 non-null   float64
#  38  ph_min                   3282 non-null   float64
#  39  ph_max                   3282 non-null   float64
#  40  leucocitos_media         3282 non-null   float64
#  41  leucocitos_min           3282 non-null   float64
#  42  leucocitos_max           3282 non-null   float64
#  43  paco2_media              3282 non-null   float64
#  44  paco2_min                3282 non-null   float64
#  45  paco2_max                3282 non-null   float64
#  46  bicarbonato_media        3282 non-null   float64
#  47  bicarbonato_min          3282 non-null   float64
#  48  bicarbonato_max          3282 non-null   float64
#  49  glucemia_media           3282 non-null   float64
#  50  glucemia_min             3282 non-null   float64
#  51  glucemia_max             3282 non-null   float64
#  52  hemoglobina_media        3282 non-null   float64
#  53  hemoglobina_min          3282 non-null   float64
#  54  hemoglobina_max          3282 non-null   float64
#  55  hr_media                 3282 non-null   float64
#  56  hr_min                   3282 non-null   float64
#  57  hr_max                   3282 non-null   float64
#  58  rr_media                 3282 non-null   float64
#  59  rr_min                   3282 non-null   float64
#  60  rr_max                   3282 non-null   float64
#  61  temp_media               3282 non-null   float64
#  62  temp_min                 3282 non-null   float64
#  63  temp_max                 3282 non-null   float64
#  64  spo2_media               3282 non-null   float64
#  65  spo2_min                 3282 non-null   float64
#  66  spo2_max                 3282 non-null   float64
#  67  map_media                3282 non-null   float64
#  68  map_min                  3282 non-null   float64
#  69  map_max                  3282 non-null   float64
#  70  fio2_media               3282 non-null   float64
#  71  fio2_min                 3282 non-null   float64
#  72  fio2_max                 3282 non-null   float64
#  73  pf_media                 3282 non-null   float64
#  74  pf_min                   3282 non-null   float64
#  75  pf_max                   3281 non-null   float64
#  76  gcs_media                3282 non-null   float64
#  77  gcs_min                  3282 non-null   int64
#  78  gcs_max                  3282 non-null   int64
#  79  diuresis_volumen_6h      3282 non-null   float64
#  80  peso_kg                  3282 non-null   float64
#  81  diuresis_ml_kg_6h        3282 non-null   float64
# dtypes: float64(69), int64(12), object(1)
# memory usage: 2.1+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  3.282000e+03  3.282000e+03  3.282000e+03  3282.000000
# mean   1.493782e+07  2.497623e+07  3.501363e+07    60.194089
# std    2.900946e+06  2.884124e+06  2.902228e+06    16.700687
# min    1.000188e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.239214e+07  2.243426e+07  3.250127e+07    50.000000
# 50%    1.491950e+07  2.497038e+07  3.504276e+07    62.000000
# 75%    1.739674e+07  2.741674e+07  3.755705e+07    73.000000
# max    1.999784e+07  2.999939e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_6_24  \
# count            3282.000000         626.000000          3282.000000
# mean                1.417124          50.244283             0.102986
# std                 1.400566          79.948621             0.303987
# min                 1.000000           6.062222             0.000000
# 25%                 1.000000          10.483750             0.000000
# 50%                 1.000000          21.678194             0.000000
# 75%                 1.000000          51.207500             0.000000
# max                36.000000         755.423611             1.000000
#
#        tiene_sepsis   sofa_media     sofa_min  ...     fio2_max     pf_media  \
# count   3282.000000  3282.000000  3282.000000  ...  3282.000000  3282.000000
# mean       0.302559     3.636718     2.237965  ...    65.469226   245.835789
# std        0.459436     2.508340     2.464447  ...    25.180818   166.997030
# min        0.000000     0.000000     0.000000  ...    30.000000    46.000000
# 25%        0.000000     1.666667     0.000000  ...    50.000000   112.045977
# 50%        0.000000     3.183333     1.000000  ...    50.000000   199.000000
# 75%        1.000000     5.000000     4.000000  ...   100.000000   341.138021
# max        1.000000    14.833333    14.000000  ...   100.000000   743.291429
#
#             pf_min       pf_max    gcs_media      gcs_min      gcs_max  \
# count  3282.000000  3281.000000  3282.000000  3282.000000  3282.000000
# mean    178.578151   347.297890     8.026879     7.205363     8.816271
# std     131.653818   276.597896     3.827090     4.099404     4.014383
# min      32.810000    51.631579     3.000000     3.000000     3.000000
# 25%      78.000000   132.500000     5.000000     3.000000     6.000000
# 50%     130.000000   260.000000     7.500000     7.000000     9.000000
# 75%     249.583333   480.000000    10.000000    10.000000    11.000000
# max     552.190000  1180.000000    15.000000    15.000000    15.000000
#
#        diuresis_volumen_6h      peso_kg  diuresis_ml_kg_6h
# count          3282.000000  3282.000000        3282.000000
# mean            514.735783    83.283404           6.633456
# std             429.714802    22.400690           5.850454
# min              19.240000    44.624000           0.213967
# 25%             210.000000    67.300000           2.436761
# 50%             389.000000    80.300000           4.859127
# 75%             685.000000    96.000000           8.636364
# max            1934.500000   146.238000          25.848168
#
# [8 rows x 81 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_6h    0
# peso_kg                0
# diuresis_ml_kg_6h      0
# Length: 82, dtype: int64

# %%
# Cada fila representa una estancia en UCI
n_pacientes = df1['subject_id'].nunique()
n_admisiones = df1['hadm_id'].nunique()
n_estancias = df1['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df1) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3198
# Admisiones únicas (hadm_id):   3264
# Estancias únicas (stay_id):    3282
# Ratio estancias/paciente:      1.026266416510319

# %%
n_pacientes = df2['subject_id'].nunique()
n_admisiones = df2['hadm_id'].nunique()
n_estancias = df2['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df2) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3198
# Admisiones únicas (hadm_id):   3264
# Estancias únicas (stay_id):    3282
# Ratio estancias/paciente:      1.026266416510319

# %%
# describe() sobre variables numéricas. Excluimos identificadores y la etiqueta
# para mostrar solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df1.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_6_24', 'horas_hasta_norad']]

df1[cols_descriptivo].describe().T
# Out:
#                         count        mean         std   min         25%  \
# anchor_age             3282.0   60.194089   16.700687  18.0   50.000000
# contador_estancia_uci  3282.0    1.417124    1.400566   1.0    1.000000
# tiene_sepsis           3282.0    0.302559    0.459436   0.0    0.000000
# sofa_media             3282.0    3.636718    2.508340   0.0    1.666667
# sofa_min               3282.0    2.237965    2.464447   0.0    0.000000
# ...                       ...         ...         ...   ...         ...
# gcs_min                3282.0    7.205363    4.099404   3.0    3.000000
# gcs_max                3282.0    8.816271    4.014383   3.0    6.000000
# diuresis_volumen_6h    3282.0  526.233394  482.470325   0.0  210.000000
# peso_kg                3282.0   83.624296   24.949103   1.0   67.300000
# diuresis_ml_kg_6h      3282.0    8.145844   39.434762   0.0    2.436761
#
#                               50%         75%          max
# anchor_age              62.000000   73.000000    91.000000
# contador_estancia_uci    1.000000    1.000000    36.000000
# tiene_sepsis             0.000000    1.000000     1.000000
# sofa_media               3.183333    5.000000    14.833333
# sofa_min                 1.000000    4.000000    14.000000
# ...                           ...         ...          ...
# gcs_min                  7.000000   10.000000    15.000000
# gcs_max                  9.000000   11.000000    15.000000
# diuresis_volumen_6h    389.000000  685.000000  5200.000000
# peso_kg                 80.300000   96.000000   272.000000
# diuresis_ml_kg_6h        4.859127    8.636364  1920.000000
#
# [76 rows x 8 columns]

# %%
# describe() sobre variables numéricas. 
# solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df2.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_6_24', 'horas_hasta_norad']]

df2[cols_descriptivo].describe().T
# Out:
#                         count        mean         std        min         25%  \
# anchor_age             3282.0   60.194089   16.700687  18.000000   50.000000
# contador_estancia_uci  3282.0    1.417124    1.400566   1.000000    1.000000
# tiene_sepsis           3282.0    0.302559    0.459436   0.000000    0.000000
# sofa_media             3282.0    3.636718    2.508340   0.000000    1.666667
# sofa_min               3282.0    2.237965    2.464447   0.000000    0.000000
# ...                       ...         ...         ...        ...         ...
# gcs_min                3282.0    7.205363    4.099404   3.000000    3.000000
# gcs_max                3282.0    8.816271    4.014383   3.000000    6.000000
# diuresis_volumen_6h    3282.0  514.735783  429.714802  19.240000  210.000000
# peso_kg                3282.0   83.283404   22.400690  44.624000   67.300000
# diuresis_ml_kg_6h      3282.0    6.633456    5.850454   0.213967    2.436761
#
#                               50%         75%          max
# anchor_age              62.000000   73.000000    91.000000
# contador_estancia_uci    1.000000    1.000000    36.000000
# tiene_sepsis             0.000000    1.000000     1.000000
# sofa_media               3.183333    5.000000    14.833333
# sofa_min                 1.000000    4.000000    14.000000
# ...                           ...         ...          ...
# gcs_min                  7.000000   10.000000    15.000000
# gcs_max                  9.000000   11.000000    15.000000
# diuresis_volumen_6h    389.000000  685.000000  1934.500000
# peso_kg                 80.300000   96.000000   146.238000
# diuresis_ml_kg_6h        4.859127    8.636364    25.848168
#
# [76 rows x 8 columns]

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_6h']

resumen_por_clase = df1.groupby('etiqueta_norad_6_24')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_6_24                0           1
# anchor_age        mean     60.081522   61.174556
#                   median   62.000000   62.000000
# lactato_max       mean      2.697011    3.305325
#                   median    1.900000    2.300000
# creatinina_max    mean      1.471501    1.678107
#                   median    1.100000    1.300000
# map_min           mean     66.945652   62.473373
#                   median   67.000000   62.500000
# hr_max            mean    101.202106  105.789941
#                   median  100.000000  104.000000
# gcs_min           mean      7.225543    7.029586
#                   median    7.000000    6.000000
# ph_min            mean      7.332344    7.296213
#                   median    7.340000    7.300000
# diuresis_ml_kg_6h mean      8.486525    5.178488
#                   median    5.060404    3.626380

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_6h']

resumen_por_clase = df2.groupby('etiqueta_norad_6_24')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_6_24                0           1
# anchor_age        mean     60.081522   61.174556
#                   median   62.000000   62.000000
# lactato_max       mean      2.641789    3.173314
#                   median    1.900000    2.300000
# creatinina_max    mean      1.433322    1.638462
#                   median    1.100000    1.300000
# map_min           mean     66.739470   62.627219
#                   median   67.000000   62.500000
# hr_max            mean    100.873302  105.393491
#                   median  100.000000  104.000000
# gcs_min           mean      7.225543    7.029586
#                   median    7.000000    6.000000
# ph_min            mean      7.333132    7.297722
#                   median    7.340000    7.300000
# diuresis_ml_kg_6h mean      6.811596    5.081847
#                   median    5.060404    3.626380

# %%
#VARIABLES CON VARIANZA MUY BAJA

excluir = ['subject_id', 'hadm_id', 'stay_id',
           'horas_hasta_norad', 'etiqueta_norad_6_24']
num_cols = [c for c in df2.select_dtypes(include=[np.number]).columns
            if c not in excluir]

# Calculamos el coeficiente de variación (std/|mean|) para comparar entre escalas
resumen_var = pd.DataFrame({
    'std': df2[num_cols].std(),
    'mean': df2[num_cols].mean(),
})
resumen_var['cv'] = resumen_var['std'] / resumen_var['mean']
resumen_var.sort_values('cv').head(20)
# Out:
#                          std        mean        cv
# ph_max              0.079633    7.371996  0.010802
# ph_media            0.083973    7.350835  0.011424
# spo2_max            1.324605   99.286411  0.013341
# ph_min              0.098355    7.329485  0.013419
# temp_max            0.762092   37.091808  0.020546
# temp_media          0.761833   36.827809  0.020686
# temp_min            0.863532   36.578658  0.023608
# spo2_media          2.420975   97.557449  0.024816
# spo2_min            4.958704   94.596892  0.052419
# map_media          13.265058   81.050351  0.163664
# hemoglobina_max     2.234319   10.826234  0.206380
# hemoglobina_media   2.228356   10.682705  0.208595
# map_max            20.401684   97.603035  0.209027
# hr_media           19.083310   89.999499  0.212038
# bicarbonato_max     4.754975   22.398537  0.212290
# hr_max             21.654566  101.338818  0.213685
# hemoglobina_min     2.272973   10.544942  0.215551
# bicarbonato_media   4.770461   22.109131  0.215769
# rr_media            4.558454   20.189214  0.225787
# bicarbonato_min     4.936322   21.841712  0.226004

# %% [markdown]
# ### Análisis de la variable objetivo

# %%
# Conteo y porcentaje por clase
conteo = df2['etiqueta_norad_6_24'].value_counts()
prevalencia = df2['etiqueta_norad_6_24'].value_counts(normalize=True)

resumen_clases = pd.DataFrame({
    'n': conteo,
    'porcentaje': (100*prevalencia).round(2)
})
resumen_clases.index = ['Negativos (no norad en 6-24h)', 'Positivos (norad en 6-24h)']
print(resumen_clases)
# Out:
#                                   n  porcentaje
# Negativos (no norad en 6-24h)  2944        89.7
# Positivos (norad en 6-24h)      338        10.3

# %%
#¿Cuándo se inicia la noradrenalina dentro de la ventana 6-24h?
positivos = df2[df2['etiqueta_norad_6_24'] == 1]['horas_hasta_norad']

print(f"Estadísticos de horas_hasta_norad en positivos (n={len(positivos)}):")
print(positivos.describe().round(2).to_string())
# Out:
# Estadísticos de horas_hasta_norad en positivos (n=338):
# count    338.00
# mean      12.39
# std        5.16
# min        6.06
# 25%        8.03
# 50%       10.94
# 75%       16.17
# max       23.90

# %%
# Histograma de horas_hasta_norad en positivos
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(positivos, bins=np.arange(6, 25, 1), color='#ff7f0e', alpha=0.8)
ax.axvline(positivos.median(), color='navy', linestyle='--',
           linewidth=2, label=f'Mediana = {positivos.median():.1f} h')
ax.axvline(positivos.mean(), color='darkred', linestyle=':',
           linewidth=2, label=f'Media = {positivos.mean():.1f} h')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Distribución temporal del evento en la clase positiva (n={len(positivos)})')
ax.set_xticks(np.arange(6, 25, 2))
ax.legend()
plt.tight_layout()
plt.show()

# %%
# ¿Cómo se componen los 3.181 negativos?
neg = df2[df2['etiqueta_norad_6_24'] == 0]

neg_norad_tardia = neg[neg['horas_hasta_norad'].notna()]
neg_sin_norad   = neg[neg['horas_hasta_norad'].isna()]

print(f"Total de negativos: {len(neg)}")
print(f"  - Recibieron noradrenalina tras las 24 h ({neg_norad_tardia['horas_hasta_norad'].min()}h a "
      f"{neg_norad_tardia['horas_hasta_norad'].max()}h): {len(neg_norad_tardia)}")
print(f"  - No recibieron noradrenalina durante la estancia:              {len(neg_sin_norad)}")
# Out:
# Total de negativos: 2944
#   - Recibieron noradrenalina tras las 24 h (24.177222222222223h a 755.4236111111111h): 288
#   - No recibieron noradrenalina durante la estancia:              2656

# %%
# Para los negativos que sí recibieron norad (pero tardíamente), ver cuándo la iniciaron
fig, ax = plt.subplots(figsize=(10, 5))
datos = neg_norad_tardia['horas_hasta_norad']
# Limitar el eje x por legibilidad (hay alguna estancia muy larga)
datos_mostrar = datos[datos <= 200]
ax.hist(datos_mostrar, bins=40, color='#1f77b4', alpha=0.7)
ax.axvline(24, color='red', linestyle='--', linewidth=2,
           label='Corte 24 h (límite de la ventana)')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Negativos con noradrenalina tardía')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Identificar pacientes que aparecen con etiqueta positiva en una estancia
por_paciente = df2.groupby('subject_id')['etiqueta_norad_6_24'].agg(['sum', 'count'])  #nos quedamos con los unos y ceros de cada "montón" y nos quedamos con la suma y counteo
pacientes_mixtos = por_paciente[(por_paciente['sum'] > 0) &
                                (por_paciente['sum'] < por_paciente['count'])] #al menios una estancia positiva y una negativa (suma tiene que dar uno y count 2 o más)

print(f"Pacientes con etiqueta mixta entre sus estancias: {len(pacientes_mixtos)}")
print(f"  (positivo en al menos una estancia, negativo en al menos otra)\n")

if len(pacientes_mixtos) > 0:
    print("Desglose:")
    print(pacientes_mixtos.head(10).to_string())
# Out:
# Pacientes con etiqueta mixta entre sus estancias: 10
#   (positivo en al menos una estancia, negativo en al menos otra)
#
# Desglose:
#             sum  count
# subject_id
# 10887818      1      2
# 11341217      1      2
# 13922987      1      2
# 14720260      1      2
# 14757759      1      2
# 14899107      1      2
# 16192841      1      2
# 16866064      1      2
# 19046107      1      2
# 19375822      1      2

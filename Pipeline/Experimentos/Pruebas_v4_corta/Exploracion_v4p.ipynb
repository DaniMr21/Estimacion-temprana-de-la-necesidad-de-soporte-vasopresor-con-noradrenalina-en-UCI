# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
ruta_df1 = r"C:\Users\danie\OneDrive\Escritorio\DATA\dataset_final_v4p.csv"
ruta_df2 = r"C:\Users\danie\OneDrive\Escritorio\DATA\definitivo_v4p.csv"

df1 = pd.read_csv(ruta_df1)
df2 = pd.read_csv(ruta_df2)

print("df1:", df1.shape)
print("df2:", df2.shape)
# Out:
# df1: (1667, 82)
# df2: (1667, 82)

# %%
# Inspección inicial
print("DF1:")
display(df1.head())
print(df1.shape)

# Ver nombres de columnas
print("\nColumnas DF1:")
print(df1.columns)
# Out:
# DF1:
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    16828280  22369507  30007565          84      M                      1
# 1    12851972  24518431  30010930          91      F                      1
# 2    11009864  25042636  30020576          73      M                      1
# 3    12847203  20057089  30024806          58      F                      1
# 4    16192578  21784851  30034693          53      M                      1
#
#    horas_hasta_norad  etiqueta_norad_3_12  tiene_sepsis  sofa_media  ...  \
# 0          35.433333                    0             1         8.0  ...
# 1                NaN                    0             0         3.0  ...
# 2                NaN                    0             0         1.0  ...
# 3                NaN                    0             0         1.0  ...
# 4                NaN                    0             1         2.0  ...
#
#    fio2_max    pf_media      pf_min  pf_max  gcs_media  gcs_min  gcs_max  \
# 0      70.0  108.750000   82.857143  145.00        3.0        3        3
# 1      40.0  400.000000   80.000000  962.50        7.0        7        7
# 2      60.0   40.000000   40.000000   40.00        7.0        7        7
# 3      40.0  187.500000  187.500000  187.50        7.5        7        8
# 4     100.0  181.111111  163.000000  203.75       10.0       10       10
#
#    diuresis_volumen_3h  peso_kg  diuresis_ml_kg_3h
# 0                  235    106.0           2.216981
# 1                  350     53.5           6.542056
# 2                  425     54.0           7.870370
# 3                  295     60.0           4.916667
# 4                  700     96.0           7.291667
#
# [5 rows x 82 columns]
# (1667, 82)
#
# Columnas DF1:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_3_12',
#        'tiene_sepsis', 'sofa_media', 'sofa_min', 'sofa_max',
#        'ventilacion_invasiva_3h', 'lactato_media', 'lactato_min',
#        'lactato_max', 'creatinina_media', 'creatinina_min', 'creatinina_max',
#        'plaquetas_media', 'plaquetas_min', 'plaquetas_max',
#        'bilirrubina_media', 'bilirrubina_min', 'bilirrubina_max', 'tp_media',
#        'tp_min', 'tp_max', 'gpt_media', 'gpt_min', 'gpt_max', 'got_media',
#        'got_min', 'got_max', 'pao2_media', 'pao2_min', 'pao2_max', 'ph_media',
#        'ph_min', 'ph_max', 'leucocitos_media', 'leucocitos_min',
#        'leucocitos_max', 'paco2_media', 'paco2_min', 'paco2_max',
#        'bicarbonato_media', 'bicarbonato_min', 'bicarbonato_max',
#        'glucemia_media', 'glucemia_min', 'glucemia_max', 'hemoglobina_media',
#        'hemoglobina_min', 'hemoglobina_max', 'hr_media', 'hr_min', 'hr_max',
#        'rr_media', 'rr_min', 'rr_max', 'temp_media', 'temp_min', 'temp_max',
#        'spo2_media', 'spo2_min', 'spo2_max', 'map_media', 'map_min', 'map_max',
#        'fio2_media', 'fio2_min', 'fio2_max', 'pf_media', 'pf_min', 'pf_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_3h', 'peso_kg',
#        'diuresis_ml_kg_3h'],
#       dtype='object')

# %%
print("DF2 (clean):")
display(df2.head())
print(df2.shape)

# Ver nombres de columnas
print("\nColumnas DF2:")
print(df2.columns)
# Out:
# DF2 (clean):
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    16828280  22369507  30007565          84      M                      1
# 1    12851972  24518431  30010930          91      F                      1
# 2    11009864  25042636  30020576          73      M                      1
# 3    12847203  20057089  30024806          58      F                      1
# 4    16192578  21784851  30034693          53      M                      1
#
#    horas_hasta_norad  etiqueta_norad_3_12  tiene_sepsis  sofa_media  ...  \
# 0          35.433333                    0             1         8.0  ...
# 1                NaN                    0             0         3.0  ...
# 2                NaN                    0             0         1.0  ...
# 3                NaN                    0             0         1.0  ...
# 4                NaN                    0             1         2.0  ...
#
#    fio2_max    pf_media      pf_min  pf_max  gcs_media  gcs_min  gcs_max  \
# 0      70.0  108.750000   82.857143  145.00        3.0        3        3
# 1      40.0  400.000000   80.000000  962.50        7.0        7        7
# 2      60.0   44.091429   40.000000   48.00        7.0        7        7
# 3      40.0  187.500000  187.500000  187.50        7.5        7        8
# 4     100.0  181.111111  163.000000  203.75       10.0       10       10
#
#    diuresis_volumen_3h  peso_kg  diuresis_ml_kg_3h
# 0                235.0    106.0           2.216981
# 1                350.0     53.5           6.542056
# 2                425.0     54.0           7.870370
# 3                295.0     60.0           4.916667
# 4                700.0     96.0           7.291667
#
# [5 rows x 82 columns]
# (1667, 82)
#
# Columnas DF2:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_3_12',
#        'tiene_sepsis', 'sofa_media', 'sofa_min', 'sofa_max',
#        'ventilacion_invasiva_3h', 'lactato_media', 'lactato_min',
#        'lactato_max', 'creatinina_media', 'creatinina_min', 'creatinina_max',
#        'plaquetas_media', 'plaquetas_min', 'plaquetas_max',
#        'bilirrubina_media', 'bilirrubina_min', 'bilirrubina_max', 'tp_media',
#        'tp_min', 'tp_max', 'gpt_media', 'gpt_min', 'gpt_max', 'got_media',
#        'got_min', 'got_max', 'pao2_media', 'pao2_min', 'pao2_max', 'ph_media',
#        'ph_min', 'ph_max', 'leucocitos_media', 'leucocitos_min',
#        'leucocitos_max', 'paco2_media', 'paco2_min', 'paco2_max',
#        'bicarbonato_media', 'bicarbonato_min', 'bicarbonato_max',
#        'glucemia_media', 'glucemia_min', 'glucemia_max', 'hemoglobina_media',
#        'hemoglobina_min', 'hemoglobina_max', 'hr_media', 'hr_min', 'hr_max',
#        'rr_media', 'rr_min', 'rr_max', 'temp_media', 'temp_min', 'temp_max',
#        'spo2_media', 'spo2_min', 'spo2_max', 'map_media', 'map_min', 'map_max',
#        'fio2_media', 'fio2_min', 'fio2_max', 'pf_media', 'pf_min', 'pf_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_3h', 'peso_kg',
#        'diuresis_ml_kg_3h'],
#       dtype='object')

# %%
df1.info() #Información general
display(df1.describe()) #Estadísticas descriptivas: cuenta, media, desviación, minimo, maximo y percentiles.
df1.isnull().sum() # Conteo de valores que no están por columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1667 entries, 0 to 1666
# Data columns (total 82 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subject_id               1667 non-null   int64
#  1   hadm_id                  1667 non-null   int64
#  2   stay_id                  1667 non-null   int64
#  3   anchor_age               1667 non-null   int64
#  4   gender                   1667 non-null   object
#  5   contador_estancia_uci    1667 non-null   int64
#  6   horas_hasta_norad        367 non-null    float64
#  7   etiqueta_norad_3_12      1667 non-null   int64
#  8   tiene_sepsis             1667 non-null   int64
#  9   sofa_media               1667 non-null   float64
#  10  sofa_min                 1667 non-null   int64
#  11  sofa_max                 1667 non-null   int64
#  12  ventilacion_invasiva_3h  1667 non-null   int64
#  13  lactato_media            1667 non-null   float64
#  14  lactato_min              1667 non-null   float64
#  15  lactato_max              1667 non-null   float64
#  16  creatinina_media         1667 non-null   float64
#  17  creatinina_min           1667 non-null   float64
#  18  creatinina_max           1667 non-null   float64
#  19  plaquetas_media          1667 non-null   float64
#  20  plaquetas_min            1667 non-null   int64
#  21  plaquetas_max            1667 non-null   int64
#  22  bilirrubina_media        1667 non-null   float64
#  23  bilirrubina_min          1667 non-null   float64
#  24  bilirrubina_max          1667 non-null   float64
#  25  tp_media                 1667 non-null   float64
#  26  tp_min                   1667 non-null   float64
#  27  tp_max                   1667 non-null   float64
#  28  gpt_media                1667 non-null   float64
#  29  gpt_min                  1667 non-null   int64
#  30  gpt_max                  1667 non-null   int64
#  31  got_media                1667 non-null   float64
#  32  got_min                  1667 non-null   int64
#  33  got_max                  1667 non-null   int64
#  34  pao2_media               1667 non-null   float64
#  35  pao2_min                 1667 non-null   int64
#  36  pao2_max                 1667 non-null   int64
#  37  ph_media                 1667 non-null   float64
#  38  ph_min                   1667 non-null   float64
#  39  ph_max                   1667 non-null   float64
#  40  leucocitos_media         1667 non-null   float64
#  41  leucocitos_min           1667 non-null   float64
#  42  leucocitos_max           1667 non-null   float64
#  43  paco2_media              1667 non-null   float64
#  44  paco2_min                1667 non-null   int64
#  45  paco2_max                1667 non-null   int64
#  46  bicarbonato_media        1667 non-null   float64
#  47  bicarbonato_min          1667 non-null   float64
#  48  bicarbonato_max          1667 non-null   float64
#  49  glucemia_media           1667 non-null   float64
#  50  glucemia_min             1667 non-null   int64
#  51  glucemia_max             1667 non-null   int64
#  52  hemoglobina_media        1667 non-null   float64
#  53  hemoglobina_min          1667 non-null   float64
#  54  hemoglobina_max          1667 non-null   float64
#  55  hr_media                 1667 non-null   float64
#  56  hr_min                   1667 non-null   int64
#  57  hr_max                   1667 non-null   int64
#  58  rr_media                 1667 non-null   float64
#  59  rr_min                   1667 non-null   int64
#  60  rr_max                   1667 non-null   int64
#  61  temp_media               1667 non-null   float64
#  62  temp_min                 1667 non-null   float64
#  63  temp_max                 1667 non-null   float64
#  64  spo2_media               1667 non-null   float64
#  65  spo2_min                 1667 non-null   int64
#  66  spo2_max                 1667 non-null   int64
#  67  map_media                1667 non-null   float64
#  68  map_min                  1667 non-null   int64
#  69  map_max                  1667 non-null   int64
#  70  fio2_media               1667 non-null   float64
#  71  fio2_min                 1667 non-null   float64
#  72  fio2_max                 1667 non-null   float64
#  73  pf_media                 1667 non-null   float64
#  74  pf_min                   1667 non-null   float64
#  75  pf_max                   1667 non-null   float64
#  76  gcs_media                1667 non-null   float64
#  77  gcs_min                  1667 non-null   int64
#  78  gcs_max                  1667 non-null   int64
#  79  diuresis_volumen_3h      1667 non-null   int64
#  80  peso_kg                  1667 non-null   float64
#  81  diuresis_ml_kg_3h        1667 non-null   float64
# dtypes: float64(48), int64(33), object(1)
# memory usage: 1.0+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  1.667000e+03  1.667000e+03  1.667000e+03  1667.000000
# mean   1.494298e+07  2.499970e+07  3.493912e+07    58.800840
# std    2.905866e+06  2.885427e+06  2.883711e+06    16.577655
# min    1.000243e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.235073e+07  2.243852e+07  3.237343e+07    48.000000
# 50%    1.494296e+07  2.502680e+07  3.489610e+07    60.000000
# 75%    1.749888e+07  2.747200e+07  3.747559e+07    70.000000
# max    1.999784e+07  2.999728e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_3_12  \
# count            1667.000000         367.000000          1667.000000
# mean                1.395321          39.907874             0.103179
# std                 1.312623          74.800999             0.304284
# min                 1.000000           3.027778             0.000000
# 25%                 1.000000           6.241667             0.000000
# 50%                 1.000000          13.433333             0.000000
# 75%                 1.000000          40.609306             0.000000
# max                36.000000         755.423611             1.000000
#
#        tiene_sepsis   sofa_media     sofa_min  ...     fio2_max      pf_media  \
# count   1667.000000  1667.000000  1667.000000  ...  1667.000000   1667.000000
# mean       0.276545     3.225005     2.281944  ...    64.357139    273.639251
# std        0.447424     2.470295     2.512572  ...    26.139340    762.417405
# min        0.000000     0.000000     0.000000  ...     0.400000     18.888889
# 25%        0.000000     1.333333     0.000000  ...    50.000000    105.000000
# 50%        0.000000     3.000000     1.000000  ...    50.000000    194.000000
# 75%        1.000000     4.666667     4.000000  ...   100.000000    345.666667
# max        1.000000    11.666667    11.000000  ...   400.000000  29750.000000
#
#              pf_min        pf_max    gcs_media      gcs_min      gcs_max  \
# count   1667.000000   1667.000000  1667.000000  1667.000000  1667.000000
# mean     229.444485    340.162995     7.324735     7.044391     7.592681
# std      751.123957    795.301809     3.945338     4.030549     4.023672
# min       14.000000     20.000000     3.000000     3.000000     3.000000
# 25%       83.000000    115.000000     3.000000     3.000000     3.000000
# 50%      143.333333    228.000000     7.000000     6.000000     7.000000
# 75%      288.000000    427.619048    10.000000    10.000000    10.000000
# max    29750.000000  29750.000000    15.000000    15.000000    15.000000
#
#        diuresis_volumen_3h      peso_kg  diuresis_ml_kg_3h
# count          1667.000000  1667.000000        1667.000000
# mean            328.891422    83.714601           4.608501
# std             324.129455    24.431315          11.555707
# min               0.000000     1.000000           0.000000
# 25%             110.000000    67.300000           1.343945
# 50%             230.000000    80.200000           2.843016
# 75%             425.000000    97.000000           5.428941
# max            2625.000000   227.000000         410.000000
#
# [8 rows x 81 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_3h    0
# peso_kg                0
# diuresis_ml_kg_3h      0
# Length: 82, dtype: int64

# %%
df2.info()
display(df2.describe()) 
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1667 entries, 0 to 1666
# Data columns (total 82 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subject_id               1667 non-null   int64
#  1   hadm_id                  1667 non-null   int64
#  2   stay_id                  1667 non-null   int64
#  3   anchor_age               1667 non-null   int64
#  4   gender                   1667 non-null   object
#  5   contador_estancia_uci    1667 non-null   int64
#  6   horas_hasta_norad        367 non-null    float64
#  7   etiqueta_norad_3_12      1667 non-null   int64
#  8   tiene_sepsis             1667 non-null   int64
#  9   sofa_media               1667 non-null   float64
#  10  sofa_min                 1667 non-null   int64
#  11  sofa_max                 1667 non-null   int64
#  12  ventilacion_invasiva_3h  1667 non-null   int64
#  13  lactato_media            1667 non-null   float64
#  14  lactato_min              1667 non-null   float64
#  15  lactato_max              1667 non-null   float64
#  16  creatinina_media         1667 non-null   float64
#  17  creatinina_min           1667 non-null   float64
#  18  creatinina_max           1667 non-null   float64
#  19  plaquetas_media          1667 non-null   float64
#  20  plaquetas_min            1667 non-null   float64
#  21  plaquetas_max            1667 non-null   float64
#  22  bilirrubina_media        1667 non-null   float64
#  23  bilirrubina_min          1667 non-null   float64
#  24  bilirrubina_max          1667 non-null   float64
#  25  tp_media                 1667 non-null   float64
#  26  tp_min                   1667 non-null   float64
#  27  tp_max                   1667 non-null   float64
#  28  gpt_media                1667 non-null   float64
#  29  gpt_min                  1667 non-null   float64
#  30  gpt_max                  1667 non-null   float64
#  31  got_media                1667 non-null   float64
#  32  got_min                  1667 non-null   float64
#  33  got_max                  1667 non-null   float64
#  34  pao2_media               1667 non-null   float64
#  35  pao2_min                 1667 non-null   float64
#  36  pao2_max                 1667 non-null   float64
#  37  ph_media                 1667 non-null   float64
#  38  ph_min                   1667 non-null   float64
#  39  ph_max                   1667 non-null   float64
#  40  leucocitos_media         1667 non-null   float64
#  41  leucocitos_min           1667 non-null   float64
#  42  leucocitos_max           1667 non-null   float64
#  43  paco2_media              1667 non-null   float64
#  44  paco2_min                1667 non-null   float64
#  45  paco2_max                1667 non-null   float64
#  46  bicarbonato_media        1667 non-null   float64
#  47  bicarbonato_min          1667 non-null   float64
#  48  bicarbonato_max          1667 non-null   float64
#  49  glucemia_media           1667 non-null   float64
#  50  glucemia_min             1667 non-null   float64
#  51  glucemia_max             1667 non-null   float64
#  52  hemoglobina_media        1667 non-null   float64
#  53  hemoglobina_min          1667 non-null   float64
#  54  hemoglobina_max          1667 non-null   float64
#  55  hr_media                 1667 non-null   float64
#  56  hr_min                   1667 non-null   float64
#  57  hr_max                   1667 non-null   float64
#  58  rr_media                 1667 non-null   float64
#  59  rr_min                   1667 non-null   float64
#  60  rr_max                   1667 non-null   float64
#  61  temp_media               1667 non-null   float64
#  62  temp_min                 1667 non-null   float64
#  63  temp_max                 1667 non-null   float64
#  64  spo2_media               1667 non-null   float64
#  65  spo2_min                 1667 non-null   float64
#  66  spo2_max                 1667 non-null   float64
#  67  map_media                1667 non-null   float64
#  68  map_min                  1667 non-null   float64
#  69  map_max                  1667 non-null   float64
#  70  fio2_media               1667 non-null   float64
#  71  fio2_min                 1667 non-null   float64
#  72  fio2_max                 1667 non-null   float64
#  73  pf_media                 1667 non-null   float64
#  74  pf_min                   1667 non-null   float64
#  75  pf_max                   1667 non-null   float64
#  76  gcs_media                1667 non-null   float64
#  77  gcs_min                  1667 non-null   int64
#  78  gcs_max                  1667 non-null   int64
#  79  diuresis_volumen_3h      1667 non-null   float64
#  80  peso_kg                  1667 non-null   float64
#  81  diuresis_ml_kg_3h        1667 non-null   float64
# dtypes: float64(69), int64(12), object(1)
# memory usage: 1.0+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  1.667000e+03  1.667000e+03  1.667000e+03  1667.000000
# mean   1.494298e+07  2.499970e+07  3.493912e+07    58.800840
# std    2.905866e+06  2.885427e+06  2.883711e+06    16.577655
# min    1.000243e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.235073e+07  2.243852e+07  3.237343e+07    48.000000
# 50%    1.494296e+07  2.502680e+07  3.489610e+07    60.000000
# 75%    1.749888e+07  2.747200e+07  3.747559e+07    70.000000
# max    1.999784e+07  2.999728e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_3_12  \
# count            1667.000000         367.000000          1667.000000
# mean                1.395321          39.907874             0.103179
# std                 1.312623          74.800999             0.304284
# min                 1.000000           3.027778             0.000000
# 25%                 1.000000           6.241667             0.000000
# 50%                 1.000000          13.433333             0.000000
# 75%                 1.000000          40.609306             0.000000
# max                36.000000         755.423611             1.000000
#
#        tiene_sepsis   sofa_media     sofa_min  ...     fio2_max     pf_media  \
# count   1667.000000  1667.000000  1667.000000  ...  1667.000000  1667.000000
# mean       0.276545     3.225005     2.281944  ...    64.243551   249.610233
# std        0.447424     2.470295     2.512572  ...    24.704753   183.482189
# min        0.000000     0.000000     0.000000  ...    30.000000    44.091429
# 25%        0.000000     1.333333     0.000000  ...    50.000000   105.000000
# 50%        0.000000     3.000000     1.000000  ...    50.000000   194.000000
# 75%        1.000000     4.666667     4.000000  ...   100.000000   345.666667
# max        1.000000    11.666667    11.000000  ...   100.000000   797.100000
#
#             pf_min       pf_max    gcs_media      gcs_min      gcs_max  \
# count  1667.000000  1667.000000  1667.000000  1667.000000  1667.000000
# mean    206.671558   315.834170     7.324735     7.044391     7.592681
# std     166.681954   261.806581     3.945338     4.030549     4.023672
# min      36.000000    48.000000     3.000000     3.000000     3.000000
# 25%      83.000000   115.000000     3.000000     3.000000     3.000000
# 50%     143.333333   228.000000     7.000000     6.000000     7.000000
# 75%     288.000000   427.619048    10.000000    10.000000    10.000000
# max     743.634286  1140.900000    15.000000    15.000000    15.000000
#
#        diuresis_volumen_3h      peso_kg  diuresis_ml_kg_3h
# count          1667.000000  1667.000000        1667.000000
# mean            321.816437    83.379822           4.177236
# std             293.376678    22.413414           4.087184
# min              10.000000    45.396000           0.093191
# 25%             110.000000    67.300000           1.343945
# 50%             230.000000    80.200000           2.843016
# 75%             425.000000    97.000000           5.428941
# max            1310.000000   146.840000          18.445025
#
# [8 rows x 81 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_3h    0
# peso_kg                0
# diuresis_ml_kg_3h      0
# Length: 82, dtype: int64

# %%
# Cada fila representa una estancia en UCI
n_pacientes = df1['subject_id'].nunique()
n_admisiones = df1['hadm_id'].nunique()
n_estancias = df1['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df1) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 1645
# Admisiones únicas (hadm_id):   1660
# Estancias únicas (stay_id):    1667
# Ratio estancias/paciente:      1.0133738601823707

# %%
n_pacientes = df2['subject_id'].nunique()
n_admisiones = df2['hadm_id'].nunique()
n_estancias = df2['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df2) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 1645
# Admisiones únicas (hadm_id):   1660
# Estancias únicas (stay_id):    1667
# Ratio estancias/paciente:      1.0133738601823707

# %%
# describe() sobre variables numéricas. Excluimos identificadores y la etiqueta
# para mostrar solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df1.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_3_12', 'horas_hasta_norad']]

df1[cols_descriptivo].describe().T
# Out:
#                         count        mean         std   min         25%  \
# anchor_age             1667.0   58.800840   16.577655  18.0   48.000000
# contador_estancia_uci  1667.0    1.395321    1.312623   1.0    1.000000
# tiene_sepsis           1667.0    0.276545    0.447424   0.0    0.000000
# sofa_media             1667.0    3.225005    2.470295   0.0    1.333333
# sofa_min               1667.0    2.281944    2.512572   0.0    0.000000
# ...                       ...         ...         ...   ...         ...
# gcs_min                1667.0    7.044391    4.030549   3.0    3.000000
# gcs_max                1667.0    7.592681    4.023672   3.0    3.000000
# diuresis_volumen_3h    1667.0  328.891422  324.129455   0.0  110.000000
# peso_kg                1667.0   83.714601   24.431315   1.0   67.300000
# diuresis_ml_kg_3h      1667.0    4.608501   11.555707   0.0    1.343945
#
#                               50%         75%          max
# anchor_age              60.000000   70.000000    91.000000
# contador_estancia_uci    1.000000    1.000000    36.000000
# tiene_sepsis             0.000000    1.000000     1.000000
# sofa_media               3.000000    4.666667    11.666667
# sofa_min                 1.000000    4.000000    11.000000
# ...                           ...         ...          ...
# gcs_min                  6.000000   10.000000    15.000000
# gcs_max                  7.000000   10.000000    15.000000
# diuresis_volumen_3h    230.000000  425.000000  2625.000000
# peso_kg                 80.200000   97.000000   227.000000
# diuresis_ml_kg_3h        2.843016    5.428941   410.000000
#
# [76 rows x 8 columns]

# %%
# describe() sobre variables numéricas. 
# solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df2.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_3_12', 'horas_hasta_norad']]

df2[cols_descriptivo].describe().T
# Out:
#                         count        mean         std        min         25%  \
# anchor_age             1667.0   58.800840   16.577655  18.000000   48.000000
# contador_estancia_uci  1667.0    1.395321    1.312623   1.000000    1.000000
# tiene_sepsis           1667.0    0.276545    0.447424   0.000000    0.000000
# sofa_media             1667.0    3.225005    2.470295   0.000000    1.333333
# sofa_min               1667.0    2.281944    2.512572   0.000000    0.000000
# ...                       ...         ...         ...        ...         ...
# gcs_min                1667.0    7.044391    4.030549   3.000000    3.000000
# gcs_max                1667.0    7.592681    4.023672   3.000000    3.000000
# diuresis_volumen_3h    1667.0  321.816437  293.376678  10.000000  110.000000
# peso_kg                1667.0   83.379822   22.413414  45.396000   67.300000
# diuresis_ml_kg_3h      1667.0    4.177236    4.087184   0.093191    1.343945
#
#                               50%         75%          max
# anchor_age              60.000000   70.000000    91.000000
# contador_estancia_uci    1.000000    1.000000    36.000000
# tiene_sepsis             0.000000    1.000000     1.000000
# sofa_media               3.000000    4.666667    11.666667
# sofa_min                 1.000000    4.000000    11.000000
# ...                           ...         ...          ...
# gcs_min                  6.000000   10.000000    15.000000
# gcs_max                  7.000000   10.000000    15.000000
# diuresis_volumen_3h    230.000000  425.000000  1310.000000
# peso_kg                 80.200000   97.000000   146.840000
# diuresis_ml_kg_3h        2.843016    5.428941    18.445025
#
# [76 rows x 8 columns]

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_3h']

resumen_por_clase = df1.groupby('etiqueta_norad_3_12')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_3_12               0           1
# anchor_age        mean    58.775251   59.023256
#                   median  60.000000   60.000000
# lactato_max       mean     2.590903    3.301744
#                   median   1.900000    2.400000
# creatinina_max    mean     1.423211    1.568605
#                   median   1.000000    1.150000
# map_min           mean    71.008027   66.645349
#                   median  71.000000   66.500000
# hr_max            mean    99.207358  105.476744
#                   median  97.000000  107.500000
# gcs_min           mean     7.048161    7.011628
#                   median   6.000000    6.000000
# ph_min            mean     7.337960    7.299012
#                   median   7.340000    7.320000
# diuresis_ml_kg_3h mean     4.725469    3.591839
#                   median   2.936242    2.242349

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_3h']

resumen_por_clase = df2.groupby('etiqueta_norad_3_12')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_3_12               0           1
# anchor_age        mean    58.775251   59.023256
#                   median  60.000000   60.000000
# lactato_max       mean     2.544351    3.089581
#                   median   1.900000    2.400000
# creatinina_max    mean     1.380803    1.515116
#                   median   1.000000    1.150000
# map_min           mean    70.853512   66.662791
#                   median  71.000000   66.500000
# hr_max            mean    98.742502  105.186512
#                   median  97.000000  107.500000
# gcs_min           mean     7.048161    7.011628
#                   median   6.000000    6.000000
# ph_min            mean     7.338428    7.303663
#                   median   7.340000    7.320000
# diuresis_ml_kg_3h mean     4.250925    3.536743
#                   median   2.936242    2.242349

# %%
#VARIABLES CON VARIANZA MUY BAJA

excluir = ['subject_id', 'hadm_id', 'stay_id',
           'horas_hasta_norad', 'etiqueta_norad_3_12']
num_cols = [c for c in df2.select_dtypes(include=[np.number]).columns
            if c not in excluir]

# Calculamos el coeficiente de variación (std/|mean|) para comparar entre escalas
resumen_var = pd.DataFrame({
    'std': df2[num_cols].std(),
    'mean': df2[num_cols].mean(),
})
resumen_var['cv'] = resumen_var['std'] / resumen_var['mean']
resumen_var.sort_values('cv').head(20)
# Out:
#                          std       mean        cv
# ph_max              0.085965   7.354373  0.011689
# ph_media            0.088290   7.344422  0.012021
# ph_min              0.095359   7.334841  0.013001
# spo2_max            1.584503  99.065987  0.015994
# temp_max            0.826981  36.897538  0.022413
# temp_media          0.831676  36.797675  0.022601
# temp_min            0.886341  36.700207  0.024151
# spo2_media          2.525134  97.648107  0.025860
# spo2_min            4.455501  95.643599  0.046584
# map_media          14.487565  82.476684  0.175656
# hemoglobina_max     2.194973  10.719076  0.204773
# hemoglobina_media   2.197301  10.696931  0.205414
# hemoglobina_min     2.210534  10.674085  0.207093
# map_max            20.262741  95.267091  0.212694
# hr_media           19.970525  91.659765  0.217877
# bicarbonato_max     4.955179  22.264319  0.222561
# hr_max             22.141438  99.407391  0.222734
# bicarbonato_media   4.957000  22.194289  0.223346
# rr_media            4.545393  20.299822  0.223913
# hr_min             19.014418  84.554217  0.224878

# %% [markdown]
# ### Análisis de la variable objetivo

# %%
# Conteo y porcentaje por clase
conteo = df2['etiqueta_norad_3_12'].value_counts()
prevalencia = df2['etiqueta_norad_3_12'].value_counts(normalize=True)

resumen_clases = pd.DataFrame({
    'n': conteo,
    'porcentaje': (100*prevalencia).round(2)
})
resumen_clases.index = ['Negativos (no norad en 3-12h)', 'Positivos (norad en 3-12h)']
print(resumen_clases)
# Out:
#                                   n  porcentaje
# Negativos (no norad en 3-12h)  1495       89.68
# Positivos (norad en 3-12h)      172       10.32

# %%
#¿Cuándo se inicia la noradrenalina dentro de la ventana 3-12h?
positivos = df2[df2['etiqueta_norad_3_12'] == 1]['horas_hasta_norad']

print(f"Estadísticos de horas_hasta_norad en positivos (n={len(positivos)}):")
print(positivos.describe().round(2).to_string())
# Out:
# Estadísticos de horas_hasta_norad en positivos (n=172):
# count    172.00
# mean       6.53
# std        2.54
# min        3.03
# 25%        4.41
# 50%        6.01
# 75%        8.39
# max       11.85

# %%
# Histograma de horas_hasta_norad en positivos
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(positivos, bins=np.arange(3, 13, 1), color='#ff7f0e', alpha=0.8)
ax.axvline(positivos.median(), color='navy', linestyle='--',
           linewidth=2, label=f'Mediana = {positivos.median():.1f} h')
ax.axvline(positivos.mean(), color='darkred', linestyle=':',
           linewidth=2, label=f'Media = {positivos.mean():.1f} h')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Distribución temporal del evento en la clase positiva (n={len(positivos)})')
ax.set_xticks(np.arange(3, 13, 1))
ax.legend()
plt.tight_layout()
plt.show()

# %%
# ¿Cómo se componen los negativos?
neg = df2[df2['etiqueta_norad_3_12'] == 0]

neg_norad_tardia = neg[neg['horas_hasta_norad'].notna()]
neg_sin_norad   = neg[neg['horas_hasta_norad'].isna()]

print(f"Total de negativos: {len(neg)}")
print(f"  - Recibieron noradrenalina tras las 12 h ({neg_norad_tardia['horas_hasta_norad'].min()}h a "
      f"{neg_norad_tardia['horas_hasta_norad'].max()}h): {len(neg_norad_tardia)}")
print(f"  - No recibieron noradrenalina durante la estancia:              {len(neg_sin_norad)}")
# Out:
# Total de negativos: 1495
#   - Recibieron noradrenalina tras las 12 h (12.073611111111113h a 755.4236111111111h): 195
#   - No recibieron noradrenalina durante la estancia:              1300

# %%
# Para los negativos que sí recibieron norad (pero tardíamente), ver cuándo la iniciaron
fig, ax = plt.subplots(figsize=(10, 5))
datos = neg_norad_tardia['horas_hasta_norad']
# Limitar el eje x por legibilidad (hay alguna estancia muy larga)
datos_mostrar = datos[datos <= 200]
ax.hist(datos_mostrar, bins=40, color='#1f77b4', alpha=0.7)
ax.axvline(12, color='red', linestyle='--', linewidth=2,
           label='Corte 12 h (límite de la ventana)')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Negativos con noradrenalina tardía')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Identificar pacientes que aparecen con etiqueta positiva en una estancia
por_paciente = df2.groupby('subject_id')['etiqueta_norad_3_12'].agg(['sum', 'count'])  #nos quedamos con los unos y ceros de cada "montón" y nos quedamos con la suma y counteo
pacientes_mixtos = por_paciente[(por_paciente['sum'] > 0) &
                                (por_paciente['sum'] < por_paciente['count'])] #al menios una estancia positiva y una negativa (suma tiene que dar uno y count 2 o más)

print(f"Pacientes con etiqueta mixta entre sus estancias: {len(pacientes_mixtos)}")
print(f"  (positivo en al menos una estancia, negativo en al menos otra)\n")

if len(pacientes_mixtos) > 0:
    print("Desglose:")
    print(pacientes_mixtos.head(10).to_string())
# Out:
# Pacientes con etiqueta mixta entre sus estancias: 4
#   (positivo en al menos una estancia, negativo en al menos otra)
#
# Desglose:
#             sum  count
# subject_id
# 10887818      1      2
# 11747893      1      2
# 13922987      1      2
# 17978664      1      2

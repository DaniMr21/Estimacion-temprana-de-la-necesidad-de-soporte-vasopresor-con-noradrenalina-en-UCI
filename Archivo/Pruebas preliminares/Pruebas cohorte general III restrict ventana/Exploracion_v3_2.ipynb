# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
ruta_df1 = r"C:\Users\danie\OneDrive\Escritorio\DATA\dataset_final_v3_2_clean.csv"
ruta_df2 = r"C:\Users\danie\OneDrive\Escritorio\DATA\definitivo_v3_2.csv"

df1 = pd.read_csv(ruta_df1)
df2 = pd.read_csv(ruta_df2)

print("df1:", df1.shape)
print("df2:", df2.shape)
# Out:
# df1: (3286, 74)
# df2: (3286, 74)

# %%
# Inspección inicial
print("DF1:")
display(df1.head())
print(df1.shape)

# Ver nombres de columnas
print("\nColumnas DF1:")
print(df1.columns)
# Out:
# DF1:
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    12861694  20205321  33282613          42      F                      1
# 1    11658100  20147092  30367285          28      F                      1
# 2    16481189  20427979  34939939          70      F                      1
# 3    12260772  20141657  38611332          72      F                      1
# 4    19561246  20468986  35868625          35      F                      1
#
#    horas_hasta_norad  etiqueta_norad_6_24  lactato_media  lactato_min  ...  \
# 0                NaN                    0       4.700000          4.7  ...
# 1          11.282778                    1       1.000000          1.0  ...
# 2                NaN                    0      16.333333         16.0  ...
# 3                NaN                    0       9.866667          9.6  ...
# 4                NaN                    0       1.333333          1.3  ...
#
#    map_max  fio2_media  fio2_min  fio2_max  gcs_media  gcs_min  gcs_max  \
# 0       88   63.333333      40.0     100.0       11.0       11       11
# 1       77   60.000000      40.0     100.0        6.0        4        8
# 2       66   50.000000      50.0      50.0       15.0       15       15
# 3       74   80.000000      80.0      80.0        3.0        3        3
# 4      111   80.000000      60.0     100.0       12.0       12       12
#
#    diuresis_volumen_6h  peso_kg  diuresis_ml_kg_6h
# 0                  385     84.0           4.583333
# 1                  550     96.0           5.729167
# 2                   40     90.7           0.441014
# 3                  100     78.3           1.277139
# 4                 1200     80.6          14.888337
#
# [5 rows x 74 columns]
# (3286, 74)
#
# Columnas DF1:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_6_24',
#        'lactato_media', 'lactato_min', 'lactato_max', 'creatinina_media',
#        'creatinina_min', 'creatinina_max', 'plaquetas_media', 'plaquetas_min',
#        'plaquetas_max', 'bilirrubina_media', 'bilirrubina_min',
#        'bilirrubina_max', 'tp_media', 'tp_min', 'tp_max', 'gpt_media',
#        'gpt_min', 'gpt_max', 'got_media', 'got_min', 'got_max', 'pao2_media',
#        'pao2_min', 'pao2_max', 'ph_media', 'ph_min', 'ph_max',
#        'leucocitos_media', 'leucocitos_min', 'leucocitos_max', 'paco2_media',
#        'paco2_min', 'paco2_max', 'bicarbonato_media', 'bicarbonato_min',
#        'bicarbonato_max', 'glucemia_media', 'glucemia_min', 'glucemia_max',
#        'hemoglobina_media', 'hemoglobina_min', 'hemoglobina_max', 'hr_media',
#        'hr_min', 'hr_max', 'rr_media', 'rr_min', 'rr_max', 'temp_media',
#        'temp_min', 'temp_max', 'spo2_media', 'spo2_min', 'spo2_max',
#        'map_media', 'map_min', 'map_max', 'fio2_media', 'fio2_min', 'fio2_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_6h', 'peso_kg',
#        'diuresis_ml_kg_6h'],
#       dtype='object')

# %%
print("DF2 (clean):")
display(df2.head())
print(df2.shape)

# Ver nombres de columnas
print("\nColumnas DF2:")
print(df2.columns)
# Out:
# DF2 (clean):
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    12861694  20205321  33282613          42      F                      1
# 1    11658100  20147092  30367285          28      F                      1
# 2    16481189  20427979  34939939          70      F                      1
# 3    12260772  20141657  38611332          72      F                      1
# 4    19561246  20468986  35868625          35      F                      1
#
#    horas_hasta_norad  etiqueta_norad_6_24  lactato_media  lactato_min  ...  \
# 0                NaN                    0       4.700000         4.70  ...
# 1          11.282778                    1       1.000000         1.00  ...
# 2                NaN                    0       9.520000         8.33  ...
# 3                NaN                    0       9.520000         8.33  ...
# 4                NaN                    0       1.333333         1.30  ...
#
#    map_max  fio2_media  fio2_min  fio2_max  gcs_media  gcs_min  gcs_max  \
# 0     88.0   63.333333      40.0     100.0       11.0       11       11
# 1     77.0   60.000000      40.0     100.0        6.0        4        8
# 2     66.0   50.000000      50.0      50.0       15.0       15       15
# 3     74.0   80.000000      80.0      80.0        3.0        3        3
# 4    111.0   80.000000      60.0     100.0       12.0       12       12
#
#    diuresis_volumen_6h  peso_kg  diuresis_ml_kg_6h
# 0                385.0     84.0           4.583333
# 1                550.0     96.0           5.729167
# 2                 40.0     90.7           0.441014
# 3                100.0     78.3           1.277139
# 4               1200.0     80.6          14.888337
#
# [5 rows x 74 columns]
# (3286, 74)
#
# Columnas DF2:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_6_24',
#        'lactato_media', 'lactato_min', 'lactato_max', 'creatinina_media',
#        'creatinina_min', 'creatinina_max', 'plaquetas_media', 'plaquetas_min',
#        'plaquetas_max', 'bilirrubina_media', 'bilirrubina_min',
#        'bilirrubina_max', 'tp_media', 'tp_min', 'tp_max', 'gpt_media',
#        'gpt_min', 'gpt_max', 'got_media', 'got_min', 'got_max', 'pao2_media',
#        'pao2_min', 'pao2_max', 'ph_media', 'ph_min', 'ph_max',
#        'leucocitos_media', 'leucocitos_min', 'leucocitos_max', 'paco2_media',
#        'paco2_min', 'paco2_max', 'bicarbonato_media', 'bicarbonato_min',
#        'bicarbonato_max', 'glucemia_media', 'glucemia_min', 'glucemia_max',
#        'hemoglobina_media', 'hemoglobina_min', 'hemoglobina_max', 'hr_media',
#        'hr_min', 'hr_max', 'rr_media', 'rr_min', 'rr_max', 'temp_media',
#        'temp_min', 'temp_max', 'spo2_media', 'spo2_min', 'spo2_max',
#        'map_media', 'map_min', 'map_max', 'fio2_media', 'fio2_min', 'fio2_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_6h', 'peso_kg',
#        'diuresis_ml_kg_6h'],
#       dtype='object')

# %%
df1.info() #Información general
display(df1.describe()) #Estadísticas descriptivas: cuenta, media, desviación, minimo, maximo y percentiles.
df1.isnull().sum() # Conteo de valores que no están por columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3286 entries, 0 to 3285
# Data columns (total 74 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             3286 non-null   int64
#  1   hadm_id                3286 non-null   int64
#  2   stay_id                3286 non-null   int64
#  3   anchor_age             3286 non-null   int64
#  4   gender                 3286 non-null   object
#  5   contador_estancia_uci  3286 non-null   int64
#  6   horas_hasta_norad      626 non-null    float64
#  7   etiqueta_norad_6_24    3286 non-null   int64
#  8   lactato_media          3286 non-null   float64
#  9   lactato_min            3286 non-null   float64
#  10  lactato_max            3286 non-null   float64
#  11  creatinina_media       3286 non-null   float64
#  12  creatinina_min         3286 non-null   float64
#  13  creatinina_max         3286 non-null   float64
#  14  plaquetas_media        3286 non-null   float64
#  15  plaquetas_min          3286 non-null   int64
#  16  plaquetas_max          3286 non-null   float64
#  17  bilirrubina_media      3286 non-null   float64
#  18  bilirrubina_min        3286 non-null   float64
#  19  bilirrubina_max        3286 non-null   float64
#  20  tp_media               3286 non-null   float64
#  21  tp_min                 3286 non-null   float64
#  22  tp_max                 3286 non-null   float64
#  23  gpt_media              3286 non-null   float64
#  24  gpt_min                3286 non-null   int64
#  25  gpt_max                3286 non-null   int64
#  26  got_media              3286 non-null   float64
#  27  got_min                3286 non-null   int64
#  28  got_max                3286 non-null   int64
#  29  pao2_media             3286 non-null   float64
#  30  pao2_min               3286 non-null   int64
#  31  pao2_max               3286 non-null   int64
#  32  ph_media               3286 non-null   float64
#  33  ph_min                 3286 non-null   float64
#  34  ph_max                 3286 non-null   float64
#  35  leucocitos_media       3286 non-null   float64
#  36  leucocitos_min         3286 non-null   float64
#  37  leucocitos_max         3286 non-null   float64
#  38  paco2_media            3286 non-null   float64
#  39  paco2_min              3286 non-null   int64
#  40  paco2_max              3286 non-null   int64
#  41  bicarbonato_media      3286 non-null   float64
#  42  bicarbonato_min        3286 non-null   float64
#  43  bicarbonato_max        3286 non-null   int64
#  44  glucemia_media         3286 non-null   float64
#  45  glucemia_min           3286 non-null   int64
#  46  glucemia_max           3286 non-null   int64
#  47  hemoglobina_media      3286 non-null   float64
#  48  hemoglobina_min        3286 non-null   float64
#  49  hemoglobina_max        3286 non-null   float64
#  50  hr_media               3286 non-null   float64
#  51  hr_min                 3286 non-null   float64
#  52  hr_max                 3286 non-null   int64
#  53  rr_media               3286 non-null   float64
#  54  rr_min                 3286 non-null   int64
#  55  rr_max                 3286 non-null   int64
#  56  temp_media             3286 non-null   float64
#  57  temp_min               3286 non-null   float64
#  58  temp_max               3286 non-null   float64
#  59  spo2_media             3286 non-null   float64
#  60  spo2_min               3286 non-null   int64
#  61  spo2_max               3286 non-null   int64
#  62  map_media              3286 non-null   float64
#  63  map_min                3286 non-null   int64
#  64  map_max                3286 non-null   int64
#  65  fio2_media             3286 non-null   float64
#  66  fio2_min               3286 non-null   float64
#  67  fio2_max               3286 non-null   float64
#  68  gcs_media              3286 non-null   float64
#  69  gcs_min                3286 non-null   int64
#  70  gcs_max                3286 non-null   int64
#  71  diuresis_volumen_6h    3286 non-null   int64
#  72  peso_kg                3286 non-null   float64
#  73  diuresis_ml_kg_6h      3286 non-null   float64
# dtypes: float64(45), int64(28), object(1)
# memory usage: 1.9+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  3.286000e+03  3.286000e+03  3.286000e+03  3286.000000
# mean   1.493980e+07  2.497766e+07  3.501341e+07    60.182593
# std    2.900873e+06  2.883332e+06  2.901862e+06    16.695103
# min    1.000188e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.240485e+07  2.243744e+07  3.250127e+07    50.000000
# 50%    1.492508e+07  2.497200e+07  3.504276e+07    62.000000
# 75%    1.739674e+07  2.741674e+07  3.755705e+07    72.750000
# max    1.999784e+07  2.999939e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_6_24  \
# count            3286.000000         626.000000          3286.000000
# mean                1.416616          50.244283             0.102861
# std                 1.399788          79.948621             0.303823
# min                 1.000000           6.062222             0.000000
# 25%                 1.000000          10.483750             0.000000
# 50%                 1.000000          21.678194             0.000000
# 75%                 1.000000          51.207500             0.000000
# max                36.000000         755.423611             1.000000
#
#        lactato_media  lactato_min  lactato_max  ...        map_max  \
# count    3286.000000   3286.00000  3286.000000  ...    3286.000000
# mean        2.526413      2.30210     2.763664  ...     129.943701
# std         2.121821      1.90493     2.454780  ...    1749.479480
# min         0.300000      0.30000     0.300000  ...     -17.000000
# 25%         1.300000      1.20000     1.300000  ...      84.000000
# 50%         1.900000      1.70000     2.000000  ...      94.000000
# 75%         2.950000      2.70000     3.200000  ...     107.000000
# max        23.200000     19.60000    26.800000  ...  100369.000000
#
#         fio2_media     fio2_min     fio2_max    gcs_media      gcs_min  \
# count  3286.000000  3286.000000  3286.000000  3286.000000  3286.000000
# mean     57.440952    50.831512    65.521896     8.024412     7.203895
# std      19.541692    18.177470    25.925936     3.829707     4.101134
# min       0.000000     0.000000     0.000000     3.000000     3.000000
# 25%      40.000000    40.000000    50.000000     5.000000     3.000000
# 50%      50.000000    50.000000    50.000000     7.500000     7.000000
# 75%      70.000000    50.000000   100.000000    10.000000    10.000000
# max     220.000000   100.000000   400.000000    15.000000    15.000000
#
#            gcs_max  diuresis_volumen_6h      peso_kg  diuresis_ml_kg_6h
# count  3286.000000          3286.000000  3286.000000        3286.000000
# mean      8.812842           526.116251    83.640213           8.141034
# std       4.017234           482.342048    24.993883          39.411031
# min       3.000000             0.000000     1.000000           0.000000
# 25%       6.000000           210.000000    67.300000           2.436761
# 50%       9.000000           387.500000    80.300000           4.859127
# 75%      11.000000           685.000000    96.000000           8.633563
# max      15.000000          5200.000000   272.000000        1920.000000
#
# [8 rows x 73 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_6h    0
# peso_kg                0
# diuresis_ml_kg_6h      0
# Length: 74, dtype: int64

# %%
df2.info()
display(df2.describe()) 
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3286 entries, 0 to 3285
# Data columns (total 74 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             3286 non-null   int64
#  1   hadm_id                3286 non-null   int64
#  2   stay_id                3286 non-null   int64
#  3   anchor_age             3286 non-null   int64
#  4   gender                 3286 non-null   object
#  5   contador_estancia_uci  3286 non-null   int64
#  6   horas_hasta_norad      626 non-null    float64
#  7   etiqueta_norad_6_24    3286 non-null   int64
#  8   lactato_media          3286 non-null   float64
#  9   lactato_min            3286 non-null   float64
#  10  lactato_max            3286 non-null   float64
#  11  creatinina_media       3286 non-null   float64
#  12  creatinina_min         3286 non-null   float64
#  13  creatinina_max         3286 non-null   float64
#  14  plaquetas_media        3286 non-null   float64
#  15  plaquetas_min          3286 non-null   float64
#  16  plaquetas_max          3286 non-null   float64
#  17  bilirrubina_media      3286 non-null   float64
#  18  bilirrubina_min        3286 non-null   float64
#  19  bilirrubina_max        3286 non-null   float64
#  20  tp_media               3286 non-null   float64
#  21  tp_min                 3286 non-null   float64
#  22  tp_max                 3286 non-null   float64
#  23  gpt_media              3286 non-null   float64
#  24  gpt_min                3286 non-null   float64
#  25  gpt_max                3286 non-null   float64
#  26  got_media              3286 non-null   float64
#  27  got_min                3286 non-null   float64
#  28  got_max                3286 non-null   float64
#  29  pao2_media             3286 non-null   float64
#  30  pao2_min               3286 non-null   float64
#  31  pao2_max               3286 non-null   float64
#  32  ph_media               3286 non-null   float64
#  33  ph_min                 3286 non-null   float64
#  34  ph_max                 3286 non-null   float64
#  35  leucocitos_media       3286 non-null   float64
#  36  leucocitos_min         3286 non-null   float64
#  37  leucocitos_max         3286 non-null   float64
#  38  paco2_media            3286 non-null   float64
#  39  paco2_min              3286 non-null   float64
#  40  paco2_max              3286 non-null   float64
#  41  bicarbonato_media      3286 non-null   float64
#  42  bicarbonato_min        3286 non-null   float64
#  43  bicarbonato_max        3286 non-null   float64
#  44  glucemia_media         3286 non-null   float64
#  45  glucemia_min           3286 non-null   float64
#  46  glucemia_max           3286 non-null   float64
#  47  hemoglobina_media      3286 non-null   float64
#  48  hemoglobina_min        3286 non-null   float64
#  49  hemoglobina_max        3286 non-null   float64
#  50  hr_media               3286 non-null   float64
#  51  hr_min                 3286 non-null   float64
#  52  hr_max                 3286 non-null   float64
#  53  rr_media               3286 non-null   float64
#  54  rr_min                 3286 non-null   float64
#  55  rr_max                 3286 non-null   float64
#  56  temp_media             3286 non-null   float64
#  57  temp_min               3286 non-null   float64
#  58  temp_max               3286 non-null   float64
#  59  spo2_media             3286 non-null   float64
#  60  spo2_min               3286 non-null   float64
#  61  spo2_max               3286 non-null   float64
#  62  map_media              3286 non-null   float64
#  63  map_min                3286 non-null   float64
#  64  map_max                3286 non-null   float64
#  65  fio2_media             3286 non-null   float64
#  66  fio2_min               3286 non-null   float64
#  67  fio2_max               3286 non-null   float64
#  68  gcs_media              3286 non-null   float64
#  69  gcs_min                3286 non-null   int64
#  70  gcs_max                3286 non-null   int64
#  71  diuresis_volumen_6h    3286 non-null   float64
#  72  peso_kg                3286 non-null   float64
#  73  diuresis_ml_kg_6h      3286 non-null   float64
# dtypes: float64(65), int64(8), object(1)
# memory usage: 1.9+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  3.286000e+03  3.286000e+03  3.286000e+03  3286.000000
# mean   1.493980e+07  2.497766e+07  3.501341e+07    60.182593
# std    2.900873e+06  2.883332e+06  2.901862e+06    16.695103
# min    1.000188e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.240485e+07  2.243744e+07  3.250127e+07    50.000000
# 50%    1.492508e+07  2.497200e+07  3.504276e+07    62.000000
# 75%    1.739674e+07  2.741674e+07  3.755705e+07    72.750000
# max    1.999784e+07  2.999939e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_6_24  \
# count            3286.000000         626.000000          3286.000000
# mean                1.416616          50.244283             0.102861
# std                 1.399788          79.948621             0.303823
# min                 1.000000           6.062222             0.000000
# 25%                 1.000000          10.483750             0.000000
# 50%                 1.000000          21.678194             0.000000
# 75%                 1.000000          51.207500             0.000000
# max                36.000000         755.423611             1.000000
#
#        lactato_media  lactato_min  lactato_max  ...      map_max   fio2_media  \
# count    3286.000000  3286.000000  3286.000000  ...  3286.000000  3286.000000
# mean        2.467830     2.240590     2.700450  ...    97.604869    57.459114
# std         1.816718     1.579962     2.137201  ...    20.381705    19.247715
# min         0.700000     0.700000     0.700000  ...    66.000000    30.000000
# 25%         1.300000     1.200000     1.300000  ...    84.000000    40.000000
# 50%         1.900000     1.700000     2.000000  ...    94.000000    50.000000
# 75%         2.950000     2.700000     3.200000  ...   107.000000    70.000000
# max         9.520000     8.330000    10.830000  ...   168.600000   100.000000
#
#          fio2_min     fio2_max    gcs_media      gcs_min      gcs_max  \
# count  3286.00000  3286.000000  3286.000000  3286.000000  3286.000000
# mean     50.92605    65.474741     8.024412     7.203895     8.812842
# std      18.01671    25.188951     3.829707     4.101134     4.017234
# min      30.00000    30.000000     3.000000     3.000000     3.000000
# 25%      40.00000    50.000000     5.000000     3.000000     6.000000
# 50%      50.00000    50.000000     7.500000     7.000000     9.000000
# 75%      50.00000   100.000000    10.000000    10.000000    11.000000
# max     100.00000   100.000000    15.000000    15.000000    15.000000
#
#        diuresis_volumen_6h      peso_kg  diuresis_ml_kg_6h
# count          3286.000000  3286.000000        3286.000000
# mean            514.595679    83.293713           6.630312
# std             429.499593    22.430035           5.847226
# min              19.400000    44.640000           0.214034
# 25%             210.000000    67.300000           2.436761
# 50%             387.500000    80.300000           4.859127
# 75%             685.000000    96.000000           8.633563
# max            1932.500000   146.360000          25.839385
#
# [8 rows x 73 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_6h    0
# peso_kg                0
# diuresis_ml_kg_6h      0
# Length: 74, dtype: int64

# %%
# Cada fila representa una estancia en UCI
n_pacientes = df1['subject_id'].nunique()
n_admisiones = df1['hadm_id'].nunique()
n_estancias = df1['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df1) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3202
# Admisiones únicas (hadm_id):   3268
# Estancias únicas (stay_id):    3286
# Ratio estancias/paciente:      1.0262336039975015

# %%
n_pacientes = df2['subject_id'].nunique()
n_admisiones = df2['hadm_id'].nunique()
n_estancias = df2['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df2) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3202
# Admisiones únicas (hadm_id):   3268
# Estancias únicas (stay_id):    3286
# Ratio estancias/paciente:      1.0262336039975015

# %%
# describe() sobre variables numéricas. Excluimos identificadores y la etiqueta
# para mostrar solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df1.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_6_24', 'horas_hasta_norad']]

df1[cols_descriptivo].describe().T
# Out:
#                         count        mean         std   min         25%  \
# anchor_age             3286.0   60.182593   16.695103  18.0   50.000000
# contador_estancia_uci  3286.0    1.416616    1.399788   1.0    1.000000
# lactato_media          3286.0    2.526413    2.121821   0.3    1.300000
# lactato_min            3286.0    2.302100    1.904930   0.3    1.200000
# lactato_max            3286.0    2.763664    2.454780   0.3    1.300000
# ...                       ...         ...         ...   ...         ...
# gcs_min                3286.0    7.203895    4.101134   3.0    3.000000
# gcs_max                3286.0    8.812842    4.017234   3.0    6.000000
# diuresis_volumen_6h    3286.0  526.116251  482.342048   0.0  210.000000
# peso_kg                3286.0   83.640213   24.993883   1.0   67.300000
# diuresis_ml_kg_6h      3286.0    8.141034   39.411031   0.0    2.436761
#
#                               50%         75%     max
# anchor_age              62.000000   72.750000    91.0
# contador_estancia_uci    1.000000    1.000000    36.0
# lactato_media            1.900000    2.950000    23.2
# lactato_min              1.700000    2.700000    19.6
# lactato_max              2.000000    3.200000    26.8
# ...                           ...         ...     ...
# gcs_min                  7.000000   10.000000    15.0
# gcs_max                  9.000000   11.000000    15.0
# diuresis_volumen_6h    387.500000  685.000000  5200.0
# peso_kg                 80.300000   96.000000   272.0
# diuresis_ml_kg_6h        4.859127    8.633563  1920.0
#
# [68 rows x 8 columns]

# %%
# describe() sobre variables numéricas. 
# solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df2.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_6_24', 'horas_hasta_norad']]

df2[cols_descriptivo].describe().T
# Out:
#                         count        mean         std        min         25%  \
# anchor_age             3286.0   60.182593   16.695103  18.000000   50.000000
# contador_estancia_uci  3286.0    1.416616    1.399788   1.000000    1.000000
# lactato_media          3286.0    2.467830    1.816718   0.700000    1.300000
# lactato_min            3286.0    2.240590    1.579962   0.700000    1.200000
# lactato_max            3286.0    2.700450    2.137201   0.700000    1.300000
# ...                       ...         ...         ...        ...         ...
# gcs_min                3286.0    7.203895    4.101134   3.000000    3.000000
# gcs_max                3286.0    8.812842    4.017234   3.000000    6.000000
# diuresis_volumen_6h    3286.0  514.595679  429.499593  19.400000  210.000000
# peso_kg                3286.0   83.293713   22.430035  44.640000   67.300000
# diuresis_ml_kg_6h      3286.0    6.630312    5.847226   0.214034    2.436761
#
#                               50%         75%          max
# anchor_age              62.000000   72.750000    91.000000
# contador_estancia_uci    1.000000    1.000000    36.000000
# lactato_media            1.900000    2.950000     9.520000
# lactato_min              1.700000    2.700000     8.330000
# lactato_max              2.000000    3.200000    10.830000
# ...                           ...         ...          ...
# gcs_min                  7.000000   10.000000    15.000000
# gcs_max                  9.000000   11.000000    15.000000
# diuresis_volumen_6h    387.500000  685.000000  1932.500000
# peso_kg                 80.300000   96.000000   146.360000
# diuresis_ml_kg_6h        4.859127    8.633563    25.839385
#
# [68 rows x 8 columns]

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_6h']

resumen_por_clase = df1.groupby('etiqueta_norad_6_24')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_6_24                0           1
# anchor_age        mean     60.068860   61.174556
#                   median   61.000000   62.000000
# lactato_max       mean      2.701560    3.305325
#                   median    1.900000    2.300000
# creatinina_max    mean      1.471235    1.678107
#                   median    1.100000    1.300000
# map_min           mean     66.960651   62.473373
#                   median   67.000000   62.500000
# hr_max            mean    101.204885  105.789941
#                   median  100.000000  104.000000
# gcs_min           mean      7.223881    7.029586
#                   median    7.000000    6.000000
# ph_min            mean      7.332151    7.296213
#                   median    7.340000    7.300000
# diuresis_ml_kg_6h mean      8.480702    5.178488
#                   median    5.060404    3.626380

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_6h']

resumen_por_clase = df2.groupby('etiqueta_norad_6_24')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_6_24                0           1
# anchor_age        mean     60.068860   61.174556
#                   median   61.000000   62.000000
# lactato_max       mean      2.646262    3.173077
#                   median    1.900000    2.300000
# creatinina_max    mean      1.433107    1.638462
#                   median    1.100000    1.300000
# map_min           mean     66.754749   62.627219
#                   median   67.000000   62.500000
# hr_max            mean    100.876526  105.393491
#                   median  100.000000  104.000000
# gcs_min           mean      7.223881    7.029586
#                   median    7.000000    6.000000
# ph_min            mean      7.332938    7.297722
#                   median    7.340000    7.300000
# diuresis_ml_kg_6h mean      6.807865    5.081720
#                   median    5.060404    3.626380

# %%
#VARIABLES CON VARIANZA MUY BAJA

excluir = ['subject_id', 'hadm_id', 'stay_id',
           'horas_hasta_norad', 'etiqueta_norad_6_24']
num_cols = [c for c in df2.select_dtypes(include=[np.number]).columns
            if c not in excluir]

# Calculamos el coeficiente de variación (std/|mean|) para comparar entre escalas
resumen_var = pd.DataFrame({
    'std': df2[num_cols].std(),
    'mean': df2[num_cols].mean(),
})
resumen_var['cv'] = resumen_var['std'] / resumen_var['mean']
resumen_var.sort_values('cv').head(20)
# Out:
#                          std        mean        cv
# ph_max              0.079629    7.371926  0.010802
# ph_media            0.083999    7.350733  0.011427
# spo2_max            1.324575   99.286366  0.013341
# ph_min              0.098507    7.329315  0.013440
# temp_max            0.764209   37.090632  0.020604
# temp_media          0.762576   36.827452  0.020707
# temp_min            0.864051   36.578579  0.023622
# spo2_media          2.420445   97.558029  0.024810
# spo2_min            4.957388   94.599209  0.052404
# map_media          13.262990   81.062945  0.163613
# hemoglobina_max     2.233381   10.827206  0.206275
# hemoglobina_media   2.227231   10.683426  0.208475
# map_max            20.381705   97.604869  0.208819
# hr_media           19.102455   90.013154  0.212218
# bicarbonato_max     4.756101   22.402617  0.212301
# hr_max             21.664430  101.341144  0.213777
# hemoglobina_min     2.271770   10.545405  0.215427
# bicarbonato_media   4.771862   22.113258  0.215792
# rr_media            4.559839   20.189146  0.225856
# bicarbonato_min     4.937792   21.845861  0.226029

# %% [markdown]
# ### Análisis de la variable objetivo

# %%
# Conteo y porcentaje por clase
conteo = df2['etiqueta_norad_6_24'].value_counts()
prevalencia = df2['etiqueta_norad_6_24'].value_counts(normalize=True)

resumen_clases = pd.DataFrame({
    'n': conteo,
    'porcentaje': (100*prevalencia).round(2)
})
resumen_clases.index = ['Negativos (no norad en 6-24h)', 'Positivos (norad en 6-24h)']
print(resumen_clases)
# Out:
#                                   n  porcentaje
# Negativos (no norad en 6-24h)  2948       89.71
# Positivos (norad en 6-24h)      338       10.29

# %%
#¿Cuándo se inicia la noradrenalina dentro de la ventana 6-24h?
positivos = df2[df2['etiqueta_norad_6_24'] == 1]['horas_hasta_norad']

print(f"Estadísticos de horas_hasta_norad en positivos (n={len(positivos)}):")
print(positivos.describe().round(2).to_string())
# Out:
# Estadísticos de horas_hasta_norad en positivos (n=338):
# count    338.00
# mean      12.39
# std        5.16
# min        6.06
# 25%        8.03
# 50%       10.94
# 75%       16.17
# max       23.90

# %%
# Histograma de horas_hasta_norad en positivos
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(positivos, bins=np.arange(6, 25, 1), color='#ff7f0e', alpha=0.8)
ax.axvline(positivos.median(), color='navy', linestyle='--',
           linewidth=2, label=f'Mediana = {positivos.median():.1f} h')
ax.axvline(positivos.mean(), color='darkred', linestyle=':',
           linewidth=2, label=f'Media = {positivos.mean():.1f} h')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title('Distribución temporal del evento en la clase positiva (n=356)')
ax.set_xticks(np.arange(6, 25, 2))
ax.legend()
plt.tight_layout()
plt.show()

# %%
# ¿Cómo se componen los 3.181 negativos?
neg = df2[df2['etiqueta_norad_6_24'] == 0]

neg_norad_tardia = neg[neg['horas_hasta_norad'].notna()]
neg_sin_norad   = neg[neg['horas_hasta_norad'].isna()]

print(f"Total de negativos: {len(neg)}")
print(f"  - Recibieron noradrenalina tras las 24 h ({neg_norad_tardia['horas_hasta_norad'].min()}h a "
      f"{neg_norad_tardia['horas_hasta_norad'].max()}h): {len(neg_norad_tardia)}")
print(f"  - No recibieron noradrenalina durante la estancia:              {len(neg_sin_norad)}")
# Out:
# Total de negativos: 2948
#   - Recibieron noradrenalina tras las 24 h (24.177222222222223h a 755.4236111111111h): 288
#   - No recibieron noradrenalina durante la estancia:              2660

# %%
# Para los negativos que sí recibieron norad (pero tardíamente), ver cuándo la iniciaron
fig, ax = plt.subplots(figsize=(10, 5))
datos = neg_norad_tardia['horas_hasta_norad']
# Limitar el eje x por legibilidad (hay alguna estancia muy larga)
datos_mostrar = datos[datos <= 200]
ax.hist(datos_mostrar, bins=40, color='#1f77b4', alpha=0.7)
ax.axvline(24, color='red', linestyle='--', linewidth=2,
           label='Corte 24 h (límite de la ventana)')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Negativos con noradrenalina tardía')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Identificar pacientes que aparecen con etiqueta positiva en una estancia
por_paciente = df2.groupby('subject_id')['etiqueta_norad_6_24'].agg(['sum', 'count'])  #nos quedamos con los unos y ceros de cada "montón" y nos quedamos con la suma y counteo
pacientes_mixtos = por_paciente[(por_paciente['sum'] > 0) &
                                (por_paciente['sum'] < por_paciente['count'])] #al menios una estancia positiva y una negativa (suma tiene que dar uno y count 2 o más)

print(f"Pacientes con etiqueta mixta entre sus estancias: {len(pacientes_mixtos)}")
print(f"  (positivo en al menos una estancia, negativo en al menos otra)\n")

if len(pacientes_mixtos) > 0:
    print("Desglose:")
    print(pacientes_mixtos.head(10).to_string())
# Out:
# Pacientes con etiqueta mixta entre sus estancias: 10
#   (positivo en al menos una estancia, negativo en al menos otra)
#
# Desglose:
#             sum  count
# subject_id
# 10887818      1      2
# 11341217      1      2
# 13922987      1      2
# 14720260      1      2
# 14757759      1      2
# 14899107      1      2
# 16192841      1      2
# 16866064      1      2
# 19046107      1      2
# 19375822      1      2

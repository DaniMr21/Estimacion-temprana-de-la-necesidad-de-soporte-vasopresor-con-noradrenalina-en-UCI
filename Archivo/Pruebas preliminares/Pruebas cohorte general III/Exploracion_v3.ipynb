# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
ruta_df1 = r"C:\Users\danie\OneDrive\Escritorio\DATA\dataset_final_v3_clean.csv"
ruta_df2 = r"C:\Users\danie\OneDrive\Escritorio\DATA\definitivo_v3.csv"

df1 = pd.read_csv(ruta_df1)
df2 = pd.read_csv(ruta_df2)

print("df1:", df1.shape)
print("df2:", df2.shape)
# Out:
# df1: (3537, 74)
# df2: (3537, 74)

# %%
# Inspección inicial
print("DF1:")
display(df1.head())
print(df1.shape)

# Ver nombres de columnas
print("\nColumnas DF1:")
print(df1.columns)
# Out:
# DF1:
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    11002360  21917964  30013458          76      F                      2
# 1    12384056  21865204  30079934          62      F                      1
# 2    14195863  21127290  30087471          77      M                      1
# 3    13013733  23026383  30126544          70      M                      1
# 4    12212143  23710046  30132321          28      F                      1
#
#    horas_hasta_norad  etiqueta_norad_6_24  lactato_media  lactato_min  ...  \
# 0                NaN                    0          1.400          1.4  ...
# 1                NaN                    0          1.700          1.7  ...
# 2          15.066667                    1          2.200          2.2  ...
# 3                NaN                    0          1.700          1.7  ...
# 4                NaN                    0          2.725          2.0  ...
#
#    map_max  fio2_media  fio2_min  fio2_max  gcs_media  gcs_min  gcs_max  \
# 0       93   53.333333      50.0      60.0       15.0       15       15
# 1      114   50.000000      50.0      50.0       15.0       15       15
# 2       72   40.000000      40.0      40.0        4.5        3        6
# 3      145   40.000000      40.0      40.0        7.0        7        7
# 4      129   53.333333      40.0      60.0        5.0        3        7
#
#    diuresis_volumen_6h  peso_kg  diuresis_ml_kg_6h
# 0                  550    105.9           5.193579
# 1                 1660    131.0          12.671756
# 2                  245     66.7           3.673163
# 3                  205     76.5           2.679739
# 4                  685     55.0          12.454545
#
# [5 rows x 74 columns]
# (3537, 74)
#
# Columnas DF1:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_6_24',
#        'lactato_media', 'lactato_min', 'lactato_max', 'creatinina_media',
#        'creatinina_min', 'creatinina_max', 'plaquetas_media', 'plaquetas_min',
#        'plaquetas_max', 'bilirrubina_media', 'bilirrubina_min',
#        'bilirrubina_max', 'tp_media', 'tp_min', 'tp_max', 'gpt_media',
#        'gpt_min', 'gpt_max', 'got_media', 'got_min', 'got_max', 'pao2_media',
#        'pao2_min', 'pao2_max', 'ph_media', 'ph_min', 'ph_max',
#        'leucocitos_media', 'leucocitos_min', 'leucocitos_max', 'paco2_media',
#        'paco2_min', 'paco2_max', 'bicarbonato_media', 'bicarbonato_min',
#        'bicarbonato_max', 'glucemia_media', 'glucemia_min', 'glucemia_max',
#        'hemoglobina_media', 'hemoglobina_min', 'hemoglobina_max', 'hr_media',
#        'hr_min', 'hr_max', 'rr_media', 'rr_min', 'rr_max', 'temp_media',
#        'temp_min', 'temp_max', 'spo2_media', 'spo2_min', 'spo2_max',
#        'map_media', 'map_min', 'map_max', 'fio2_media', 'fio2_min', 'fio2_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_6h', 'peso_kg',
#        'diuresis_ml_kg_6h'],
#       dtype='object')

# %%
print("DF2 (clean):")
display(df2.head())
print(df2.shape)

# Ver nombres de columnas
print("\nColumnas DF2:")
print(df2.columns)
# Out:
# DF2 (clean):
#    subject_id   hadm_id   stay_id  anchor_age gender  contador_estancia_uci  \
# 0    11002360  21917964  30013458          76      F                      2
# 1    12384056  21865204  30079934          62      F                      1
# 2    14195863  21127290  30087471          77      M                      1
# 3    13013733  23026383  30126544          70      M                      1
# 4    12212143  23710046  30132321          28      F                      1
#
#    horas_hasta_norad  etiqueta_norad_6_24  lactato_media  lactato_min  ...  \
# 0                NaN                    0          1.400          1.4  ...
# 1                NaN                    0          1.700          1.7  ...
# 2          15.066667                    1          2.200          2.2  ...
# 3                NaN                    0          1.700          1.7  ...
# 4                NaN                    0          2.725          2.0  ...
#
#    map_max  fio2_media  fio2_min  fio2_max  gcs_media  gcs_min  gcs_max  \
# 0     93.0   53.333333      50.0      60.0       15.0       15       15
# 1    114.0   50.000000      50.0      50.0       15.0       15       15
# 2     72.0   40.000000      40.0      40.0        4.5        3        6
# 3    145.0   40.000000      40.0      40.0        7.0        7        7
# 4    129.0   53.333333      40.0      60.0        5.0        3        7
#
#    diuresis_volumen_6h  peso_kg  diuresis_ml_kg_6h
# 0                550.0    105.9           5.193579
# 1               1660.0    131.0          12.671756
# 2                245.0     66.7           3.673163
# 3                205.0     76.5           2.679739
# 4                685.0     55.0          12.454545
#
# [5 rows x 74 columns]
# (3537, 74)
#
# Columnas DF2:
# Index(['subject_id', 'hadm_id', 'stay_id', 'anchor_age', 'gender',
#        'contador_estancia_uci', 'horas_hasta_norad', 'etiqueta_norad_6_24',
#        'lactato_media', 'lactato_min', 'lactato_max', 'creatinina_media',
#        'creatinina_min', 'creatinina_max', 'plaquetas_media', 'plaquetas_min',
#        'plaquetas_max', 'bilirrubina_media', 'bilirrubina_min',
#        'bilirrubina_max', 'tp_media', 'tp_min', 'tp_max', 'gpt_media',
#        'gpt_min', 'gpt_max', 'got_media', 'got_min', 'got_max', 'pao2_media',
#        'pao2_min', 'pao2_max', 'ph_media', 'ph_min', 'ph_max',
#        'leucocitos_media', 'leucocitos_min', 'leucocitos_max', 'paco2_media',
#        'paco2_min', 'paco2_max', 'bicarbonato_media', 'bicarbonato_min',
#        'bicarbonato_max', 'glucemia_media', 'glucemia_min', 'glucemia_max',
#        'hemoglobina_media', 'hemoglobina_min', 'hemoglobina_max', 'hr_media',
#        'hr_min', 'hr_max', 'rr_media', 'rr_min', 'rr_max', 'temp_media',
#        'temp_min', 'temp_max', 'spo2_media', 'spo2_min', 'spo2_max',
#        'map_media', 'map_min', 'map_max', 'fio2_media', 'fio2_min', 'fio2_max',
#        'gcs_media', 'gcs_min', 'gcs_max', 'diuresis_volumen_6h', 'peso_kg',
#        'diuresis_ml_kg_6h'],
#       dtype='object')

# %%
df1.info() #Información general
display(df1.describe()) #Estadísticas descriptivas: cuenta, media, desviación, minimo, maximo y percentiles.
df1.isnull().sum() # Conteo de valores que no están por columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3537 entries, 0 to 3536
# Data columns (total 74 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             3537 non-null   int64
#  1   hadm_id                3537 non-null   int64
#  2   stay_id                3537 non-null   int64
#  3   anchor_age             3537 non-null   int64
#  4   gender                 3537 non-null   object
#  5   contador_estancia_uci  3537 non-null   int64
#  6   horas_hasta_norad      644 non-null    float64
#  7   etiqueta_norad_6_24    3537 non-null   int64
#  8   lactato_media          3537 non-null   float64
#  9   lactato_min            3537 non-null   float64
#  10  lactato_max            3537 non-null   float64
#  11  creatinina_media       3537 non-null   float64
#  12  creatinina_min         3537 non-null   float64
#  13  creatinina_max         3537 non-null   float64
#  14  plaquetas_media        3537 non-null   float64
#  15  plaquetas_min          3537 non-null   int64
#  16  plaquetas_max          3537 non-null   float64
#  17  bilirrubina_media      3537 non-null   float64
#  18  bilirrubina_min        3537 non-null   float64
#  19  bilirrubina_max        3537 non-null   float64
#  20  tp_media               3537 non-null   float64
#  21  tp_min                 3537 non-null   float64
#  22  tp_max                 3537 non-null   float64
#  23  gpt_media              3537 non-null   float64
#  24  gpt_min                3537 non-null   int64
#  25  gpt_max                3537 non-null   int64
#  26  got_media              3537 non-null   float64
#  27  got_min                3537 non-null   int64
#  28  got_max                3537 non-null   int64
#  29  pao2_media             3537 non-null   float64
#  30  pao2_min               3537 non-null   int64
#  31  pao2_max               3537 non-null   int64
#  32  ph_media               3537 non-null   float64
#  33  ph_min                 3537 non-null   float64
#  34  ph_max                 3537 non-null   float64
#  35  leucocitos_media       3537 non-null   float64
#  36  leucocitos_min         3537 non-null   float64
#  37  leucocitos_max         3537 non-null   float64
#  38  paco2_media            3537 non-null   float64
#  39  paco2_min              3537 non-null   int64
#  40  paco2_max              3537 non-null   int64
#  41  bicarbonato_media      3537 non-null   float64
#  42  bicarbonato_min        3537 non-null   float64
#  43  bicarbonato_max        3537 non-null   int64
#  44  glucemia_media         3537 non-null   float64
#  45  glucemia_min           3537 non-null   int64
#  46  glucemia_max           3537 non-null   int64
#  47  hemoglobina_media      3537 non-null   float64
#  48  hemoglobina_min        3537 non-null   float64
#  49  hemoglobina_max        3537 non-null   float64
#  50  hr_media               3537 non-null   float64
#  51  hr_min                 3537 non-null   float64
#  52  hr_max                 3537 non-null   int64
#  53  rr_media               3537 non-null   float64
#  54  rr_min                 3537 non-null   int64
#  55  rr_max                 3537 non-null   int64
#  56  temp_media             3537 non-null   float64
#  57  temp_min               3537 non-null   float64
#  58  temp_max               3537 non-null   float64
#  59  spo2_media             3537 non-null   float64
#  60  spo2_min               3537 non-null   int64
#  61  spo2_max               3537 non-null   int64
#  62  map_media              3537 non-null   float64
#  63  map_min                3537 non-null   int64
#  64  map_max                3537 non-null   int64
#  65  fio2_media             3537 non-null   float64
#  66  fio2_min               3537 non-null   float64
#  67  fio2_max               3537 non-null   float64
#  68  gcs_media              3537 non-null   float64
#  69  gcs_min                3537 non-null   int64
#  70  gcs_max                3537 non-null   int64
#  71  diuresis_volumen_6h    3537 non-null   int64
#  72  peso_kg                3537 non-null   float64
#  73  diuresis_ml_kg_6h      3537 non-null   float64
# dtypes: float64(45), int64(28), object(1)
# memory usage: 2.0+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  3.537000e+03  3.537000e+03  3.537000e+03  3537.000000
# mean   1.493205e+07  2.499210e+07  3.500802e+07    60.072943
# std    2.896301e+06  2.884177e+06  2.899885e+06    16.920739
# min    1.000188e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.238642e+07  2.245423e+07  3.248979e+07    49.000000
# 50%    1.490109e+07  2.498707e+07  3.502631e+07    61.000000
# 75%    1.739376e+07  2.745011e+07  3.755747e+07    73.000000
# max    1.999784e+07  2.999939e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_6_24  \
# count            3537.000000         644.000000          3537.000000
# mean                1.507492          49.092231             0.100650
# std                 1.578458          79.115592             0.300908
# min                 1.000000           6.000000             0.000000
# 25%                 1.000000          10.108819             0.000000
# 50%                 1.000000          20.793750             0.000000
# 75%                 1.000000          49.252500             0.000000
# max                40.000000         755.423611             1.000000
#
#        lactato_media  lactato_min  lactato_max  ...        map_max  \
# count    3537.000000  3537.000000  3537.000000  ...    3537.000000
# mean        2.602815     2.368928     2.848346  ...     127.705400
# std         2.326858     2.093412     2.669314  ...    1686.282888
# min         0.300000     0.300000     0.300000  ...     -17.000000
# 25%         1.300000     1.200000     1.300000  ...      84.000000
# 50%         1.900000     1.700000     2.000000  ...      94.000000
# 75%         3.000000     2.700000     3.200000  ...     107.000000
# max        24.000000    23.000000    26.800000  ...  100369.000000
#
#         fio2_media     fio2_min     fio2_max    gcs_media     gcs_min  \
# count  3537.000000  3537.000000  3537.000000  3537.000000  3537.00000
# mean     57.463315    50.936203    65.449237     8.071896     7.25728
# std      19.665276    18.373666    25.940203     3.855228     4.12461
# min       0.000000     0.000000     0.000000     3.000000     3.00000
# 25%      40.000000    40.000000    50.000000     5.000000     3.00000
# 50%      50.000000    50.000000    50.000000     7.666667     7.00000
# 75%      70.000000    50.000000   100.000000    10.200000    10.00000
# max     220.000000   100.000000   400.000000    15.000000    15.00000
#
#            gcs_max  diuresis_volumen_6h      peso_kg  diuresis_ml_kg_6h
# count  3537.000000          3537.000000  3537.000000        3537.000000
# mean      8.855245           526.026011    83.334928           8.092386
# std       4.042194           483.639752    24.839242          38.087258
# min       3.000000             0.000000     1.000000           0.000000
# 25%       6.000000           205.000000    67.000000           2.427184
# 50%       9.000000           385.000000    80.000000           4.854369
# 75%      11.000000           695.000000    95.800000           8.720930
# max      15.000000          5200.000000   272.000000        1920.000000
#
# [8 rows x 73 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_6h    0
# peso_kg                0
# diuresis_ml_kg_6h      0
# Length: 74, dtype: int64

# %%
df2.info()
display(df2.describe()) 
df2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3537 entries, 0 to 3536
# Data columns (total 74 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   subject_id             3537 non-null   int64
#  1   hadm_id                3537 non-null   int64
#  2   stay_id                3537 non-null   int64
#  3   anchor_age             3537 non-null   int64
#  4   gender                 3537 non-null   object
#  5   contador_estancia_uci  3537 non-null   int64
#  6   horas_hasta_norad      644 non-null    float64
#  7   etiqueta_norad_6_24    3537 non-null   int64
#  8   lactato_media          3537 non-null   float64
#  9   lactato_min            3537 non-null   float64
#  10  lactato_max            3537 non-null   float64
#  11  creatinina_media       3537 non-null   float64
#  12  creatinina_min         3537 non-null   float64
#  13  creatinina_max         3537 non-null   float64
#  14  plaquetas_media        3537 non-null   float64
#  15  plaquetas_min          3537 non-null   float64
#  16  plaquetas_max          3537 non-null   float64
#  17  bilirrubina_media      3537 non-null   float64
#  18  bilirrubina_min        3537 non-null   float64
#  19  bilirrubina_max        3537 non-null   float64
#  20  tp_media               3537 non-null   float64
#  21  tp_min                 3537 non-null   float64
#  22  tp_max                 3537 non-null   float64
#  23  gpt_media              3537 non-null   float64
#  24  gpt_min                3537 non-null   float64
#  25  gpt_max                3537 non-null   float64
#  26  got_media              3537 non-null   float64
#  27  got_min                3537 non-null   float64
#  28  got_max                3537 non-null   float64
#  29  pao2_media             3537 non-null   float64
#  30  pao2_min               3537 non-null   float64
#  31  pao2_max               3537 non-null   float64
#  32  ph_media               3537 non-null   float64
#  33  ph_min                 3537 non-null   float64
#  34  ph_max                 3537 non-null   float64
#  35  leucocitos_media       3537 non-null   float64
#  36  leucocitos_min         3537 non-null   float64
#  37  leucocitos_max         3537 non-null   float64
#  38  paco2_media            3537 non-null   float64
#  39  paco2_min              3537 non-null   float64
#  40  paco2_max              3537 non-null   float64
#  41  bicarbonato_media      3537 non-null   float64
#  42  bicarbonato_min        3537 non-null   float64
#  43  bicarbonato_max        3537 non-null   float64
#  44  glucemia_media         3537 non-null   float64
#  45  glucemia_min           3537 non-null   float64
#  46  glucemia_max           3537 non-null   float64
#  47  hemoglobina_media      3537 non-null   float64
#  48  hemoglobina_min        3537 non-null   float64
#  49  hemoglobina_max        3537 non-null   float64
#  50  hr_media               3537 non-null   float64
#  51  hr_min                 3537 non-null   float64
#  52  hr_max                 3537 non-null   float64
#  53  rr_media               3537 non-null   float64
#  54  rr_min                 3537 non-null   float64
#  55  rr_max                 3537 non-null   float64
#  56  temp_media             3537 non-null   float64
#  57  temp_min               3537 non-null   float64
#  58  temp_max               3537 non-null   float64
#  59  spo2_media             3537 non-null   float64
#  60  spo2_min               3537 non-null   float64
#  61  spo2_max               3537 non-null   float64
#  62  map_media              3537 non-null   float64
#  63  map_min                3537 non-null   float64
#  64  map_max                3537 non-null   float64
#  65  fio2_media             3537 non-null   float64
#  66  fio2_min               3537 non-null   float64
#  67  fio2_max               3537 non-null   float64
#  68  gcs_media              3537 non-null   float64
#  69  gcs_min                3537 non-null   int64
#  70  gcs_max                3537 non-null   int64
#  71  diuresis_volumen_6h    3537 non-null   float64
#  72  peso_kg                3537 non-null   float64
#  73  diuresis_ml_kg_6h      3537 non-null   float64
# dtypes: float64(65), int64(8), object(1)
# memory usage: 2.0+ MB
#          subject_id       hadm_id       stay_id   anchor_age  \
# count  3.537000e+03  3.537000e+03  3.537000e+03  3537.000000
# mean   1.493205e+07  2.499210e+07  3.500802e+07    60.072943
# std    2.896301e+06  2.884177e+06  2.899885e+06    16.920739
# min    1.000188e+07  2.000200e+07  3.000756e+07    18.000000
# 25%    1.238642e+07  2.245423e+07  3.248979e+07    49.000000
# 50%    1.490109e+07  2.498707e+07  3.502631e+07    61.000000
# 75%    1.739376e+07  2.745011e+07  3.755747e+07    73.000000
# max    1.999784e+07  2.999939e+07  3.998923e+07    91.000000
#
#        contador_estancia_uci  horas_hasta_norad  etiqueta_norad_6_24  \
# count            3537.000000         644.000000          3537.000000
# mean                1.507492          49.092231             0.100650
# std                 1.578458          79.115592             0.300908
# min                 1.000000           6.000000             0.000000
# 25%                 1.000000          10.108819             0.000000
# 50%                 1.000000          20.793750             0.000000
# 75%                 1.000000          49.252500             0.000000
# max                40.000000         755.423611             1.000000
#
#        lactato_media  lactato_min  lactato_max  ...      map_max   fio2_media  \
# count    3537.000000  3537.000000  3537.000000  ...  3537.000000  3537.000000
# mean        2.530606     2.303361     2.774604  ...    97.559729    57.489307
# std         1.944562     1.724115     2.294995  ...    20.404784    19.375980
# min         0.700000     0.700000     0.700000  ...    66.000000    30.000000
# 25%         1.300000     1.200000     1.300000  ...    84.000000    40.000000
# 50%         1.900000     1.700000     2.000000  ...    94.000000    50.000000
# 75%         3.000000     2.700000     3.200000  ...   107.000000    70.000000
# max        10.200000     9.328000    11.756000  ...   168.560000   100.000000
#
#           fio2_min     fio2_max    gcs_media     gcs_min      gcs_max  \
# count  3537.000000  3537.000000  3537.000000  3537.00000  3537.000000
# mean     51.044671    65.414193     8.071896     7.25728     8.855245
# std      18.190086    25.240283     3.855228     4.12461     4.042194
# min      30.000000    30.000000     3.000000     3.00000     3.000000
# 25%      40.000000    50.000000     5.000000     3.00000     6.000000
# 50%      50.000000    50.000000     7.666667     7.00000     9.000000
# 75%      50.000000   100.000000    10.200000    10.00000    11.000000
# max     100.000000   100.000000    15.000000    15.00000    15.000000
#
#        diuresis_volumen_6h      peso_kg  diuresis_ml_kg_6h
# count          3537.000000  3537.000000        3537.000000
# mean            514.391858    82.995760           6.648933
# std             430.653532    22.335614           5.888671
# min              15.000000    44.500000           0.195015
# 25%             205.000000    67.000000           2.427184
# 50%             385.000000    80.000000           4.854369
# 75%             695.000000    95.800000           8.720930
# max            1932.000000   145.284000          25.837190
#
# [8 rows x 73 columns]
# subject_id             0
# hadm_id                0
# stay_id                0
# anchor_age             0
# gender                 0
#                       ..
# gcs_min                0
# gcs_max                0
# diuresis_volumen_6h    0
# peso_kg                0
# diuresis_ml_kg_6h      0
# Length: 74, dtype: int64

# %%
# Cada fila representa una estancia en UCI
n_pacientes = df1['subject_id'].nunique()
n_admisiones = df1['hadm_id'].nunique()
n_estancias = df1['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df1) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3444
# Admisiones únicas (hadm_id):   3517
# Estancias únicas (stay_id):    3537
# Ratio estancias/paciente:      1.0270034843205575

# %%
n_pacientes = df2['subject_id'].nunique()
n_admisiones = df2['hadm_id'].nunique()
n_estancias = df2['stay_id'].nunique()

print(f"Pacientes únicos (subject_id): {n_pacientes}")
print(f"Admisiones únicas (hadm_id):   {n_admisiones}")
print(f"Estancias únicas (stay_id):    {n_estancias}")
print(f"Ratio estancias/paciente:      {len(df2) / n_pacientes}")
# Out:
# Pacientes únicos (subject_id): 3444
# Admisiones únicas (hadm_id):   3517
# Estancias únicas (stay_id):    3537
# Ratio estancias/paciente:      1.0270034843205575

# %%
# describe() sobre variables numéricas. Excluimos identificadores y la etiqueta
# para mostrar solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df1.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_6_24', 'horas_hasta_norad']]

df1[cols_descriptivo].describe().T
# Out:
#                         count        mean         std   min         25%  \
# anchor_age             3537.0   60.072943   16.920739  18.0   49.000000
# contador_estancia_uci  3537.0    1.507492    1.578458   1.0    1.000000
# lactato_media          3537.0    2.602815    2.326858   0.3    1.300000
# lactato_min            3537.0    2.368928    2.093412   0.3    1.200000
# lactato_max            3537.0    2.848346    2.669314   0.3    1.300000
# ...                       ...         ...         ...   ...         ...
# gcs_min                3537.0    7.257280    4.124610   3.0    3.000000
# gcs_max                3537.0    8.855245    4.042194   3.0    6.000000
# diuresis_volumen_6h    3537.0  526.026011  483.639752   0.0  205.000000
# peso_kg                3537.0   83.334928   24.839242   1.0   67.000000
# diuresis_ml_kg_6h      3537.0    8.092386   38.087258   0.0    2.427184
#
#                               50%        75%     max
# anchor_age              61.000000   73.00000    91.0
# contador_estancia_uci    1.000000    1.00000    40.0
# lactato_media            1.900000    3.00000    24.0
# lactato_min              1.700000    2.70000    23.0
# lactato_max              2.000000    3.20000    26.8
# ...                           ...        ...     ...
# gcs_min                  7.000000   10.00000    15.0
# gcs_max                  9.000000   11.00000    15.0
# diuresis_volumen_6h    385.000000  695.00000  5200.0
# peso_kg                 80.000000   95.80000   272.0
# diuresis_ml_kg_6h        4.854369    8.72093  1920.0
#
# [68 rows x 8 columns]

# %%
# describe() sobre variables numéricas. 
# solo lo que tiene sentido clínico.
cols_descriptivo = [c for c in df2.columns
                    if c not in ['subject_id', 'hadm_id', 'stay_id',
                                 'etiqueta_norad_6_24', 'horas_hasta_norad']]

df2[cols_descriptivo].describe().T
# Out:
#                         count        mean         std        min         25%  \
# anchor_age             3537.0   60.072943   16.920739  18.000000   49.000000
# contador_estancia_uci  3537.0    1.507492    1.578458   1.000000    1.000000
# lactato_media          3537.0    2.530606    1.944562   0.700000    1.300000
# lactato_min            3537.0    2.303361    1.724115   0.700000    1.200000
# lactato_max            3537.0    2.774604    2.294995   0.700000    1.300000
# ...                       ...         ...         ...        ...         ...
# gcs_min                3537.0    7.257280    4.124610   3.000000    3.000000
# gcs_max                3537.0    8.855245    4.042194   3.000000    6.000000
# diuresis_volumen_6h    3537.0  514.391858  430.653532  15.000000  205.000000
# peso_kg                3537.0   82.995760   22.335614  44.500000   67.000000
# diuresis_ml_kg_6h      3537.0    6.648933    5.888671   0.195015    2.427184
#
#                               50%        75%         max
# anchor_age              61.000000   73.00000    91.00000
# contador_estancia_uci    1.000000    1.00000    40.00000
# lactato_media            1.900000    3.00000    10.20000
# lactato_min              1.700000    2.70000     9.32800
# lactato_max              2.000000    3.20000    11.75600
# ...                           ...        ...         ...
# gcs_min                  7.000000   10.00000    15.00000
# gcs_max                  9.000000   11.00000    15.00000
# diuresis_volumen_6h    385.000000  695.00000  1932.00000
# peso_kg                 80.000000   95.80000   145.28400
# diuresis_ml_kg_6h        4.854369    8.72093    25.83719
#
# [68 rows x 8 columns]

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_6h']

resumen_por_clase = df1.groupby('etiqueta_norad_6_24')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_6_24                0           1
# anchor_age        mean     59.910720   61.522472
#                   median   61.000000   63.000000
# lactato_max       mean      2.776737    3.488202
#                   median    1.900000    2.400000
# creatinina_max    mean      1.454888    1.716854
#                   median    1.100000    1.300000
# map_min           mean     66.917322   62.174157
#                   median   67.000000   62.000000
# hr_max            mean    101.308708  105.882022
#                   median  100.000000  104.500000
# gcs_min           mean      7.288274    6.980337
#                   median    7.000000    6.000000
# ph_min            mean      7.330707    7.293511
#                   median    7.340000    7.300000
# diuresis_ml_kg_6h mean      8.429882    5.076725
#                   median    5.069930    3.519781

# %%
# describe() estratificado por la clase objetivo
variables_clave = ['anchor_age', 'lactato_max', 'creatinina_max', 'map_min',
                   'hr_max', 'gcs_min', 'ph_min', 'diuresis_ml_kg_6h']

resumen_por_clase = df2.groupby('etiqueta_norad_6_24')[variables_clave].agg(['mean', 'median'])
resumen_por_clase.T
# Out:
# etiqueta_norad_6_24                0           1
# anchor_age        mean     59.910720   61.522472
#                   median   61.000000   63.000000
# lactato_max       mean      2.709760    3.354011
#                   median    1.900000    2.400000
# creatinina_max    mean      1.415687    1.659270
#                   median    1.100000    1.300000
# map_min           mean     66.712355   62.339888
#                   median   67.000000   62.000000
# hr_max            mean    101.005973  105.528090
#                   median  100.000000  104.500000
# gcs_min           mean      7.288274    6.980337
#                   median    7.000000    6.000000
# ph_min            mean      7.331644    7.295674
#                   median    7.340000    7.300000
# diuresis_ml_kg_6h mean      6.835244    4.984169
#                   median    5.069930    3.519781

# %%
#VARIABLES CON VARIANZA MUY BAJA

excluir = ['subject_id', 'hadm_id', 'stay_id',
           'horas_hasta_norad', 'etiqueta_norad_6_24']
num_cols = [c for c in df2.select_dtypes(include=[np.number]).columns
            if c not in excluir]

# Calculamos el coeficiente de variación (std/|mean|) para comparar entre escalas
resumen_var = pd.DataFrame({
    'std': df2[num_cols].std(),
    'mean': df2[num_cols].mean(),
})
resumen_var['cv'] = resumen_var['std'] / resumen_var['mean']
resumen_var.sort_values('cv').head(20)
# Out:
#                          std        mean        cv
# ph_max              0.080858    7.370498  0.010971
# ph_media            0.085699    7.349301  0.011661
# spo2_max            1.321464   99.290359  0.013309
# ph_min              0.100153    7.328024  0.013667
# temp_max            0.771250   37.077176  0.020801
# temp_media          0.779749   36.811885  0.021182
# temp_min            0.879836   36.561402  0.024065
# spo2_media          2.475868   97.534077  0.025385
# spo2_min            5.171541   94.512016  0.054718
# map_media          13.247698   81.013228  0.163525
# hemoglobina_max     2.235326   10.848230  0.206054
# hemoglobina_media   2.234055   10.704687  0.208699
# map_max            20.404784   97.559729  0.209152
# bicarbonato_max     4.726795   22.311530  0.211854
# hr_media           19.086961   90.025971  0.212016
# hr_max             21.718628  101.461125  0.214059
# hemoglobina_min     2.283763   10.563444  0.216195
# bicarbonato_media   4.806420   22.019744  0.218278
# rr_media            4.566452   20.159096  0.226521
# hr_min             18.302011   80.348092  0.227784

# %% [markdown]
# ### Análisis de la variable objetivo

# %%
# Conteo y porcentaje por clase
conteo = df2['etiqueta_norad_6_24'].value_counts()
prevalencia = df2['etiqueta_norad_6_24'].value_counts(normalize=True)

resumen_clases = pd.DataFrame({
    'n': conteo,
    'porcentaje': (100*prevalencia).round(2)
})
resumen_clases.index = ['Negativos (no norad en 6-24h)', 'Positivos (norad en 6-24h)']
print(resumen_clases)
# Out:
#                                   n  porcentaje
# Negativos (no norad en 6-24h)  3181       89.93
# Positivos (norad en 6-24h)      356       10.07

# %%
#¿Cuándo se inicia la noradrenalina dentro de la ventana 6-24h?
positivos = df2[df2['etiqueta_norad_6_24'] == 1]['horas_hasta_norad']

print(f"Estadísticos de horas_hasta_norad en positivos (n={len(positivos)}):")
print(positivos.describe().round(2).to_string())
# Out:
# Estadísticos de horas_hasta_norad en positivos (n=356):
# count    356.00
# mean      12.22
# std        5.11
# min        6.00
# 25%        7.88
# 50%       10.81
# 75%       15.66
# max       23.90

# %%
# Histograma de horas_hasta_norad en positivos
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(positivos, bins=np.arange(6, 25, 1), color='#ff7f0e', alpha=0.8)
ax.axvline(positivos.median(), color='navy', linestyle='--',
           linewidth=2, label=f'Mediana = {positivos.median():.1f} h')
ax.axvline(positivos.mean(), color='darkred', linestyle=':',
           linewidth=2, label=f'Media = {positivos.mean():.1f} h')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title('Distribución temporal del evento en la clase positiva (n=356)')
ax.set_xticks(np.arange(6, 25, 2))
ax.legend()
plt.tight_layout()
plt.show()

# %%
# ¿Cómo se componen los 3.181 negativos?
neg = df2[df2['etiqueta_norad_6_24'] == 0]

neg_norad_tardia = neg[neg['horas_hasta_norad'].notna()]
neg_sin_norad   = neg[neg['horas_hasta_norad'].isna()]

print(f"Total de negativos: {len(neg)}")
print(f"  - Recibieron noradrenalina tras las 24 h ({neg_norad_tardia['horas_hasta_norad'].min()}h a "
      f"{neg_norad_tardia['horas_hasta_norad'].max()}h): {len(neg_norad_tardia)}")
print(f"  - No recibieron noradrenalina durante la estancia:              {len(neg_sin_norad)}")
# Out:
# Total de negativos: 3181
#   - Recibieron noradrenalina tras las 24 h (24.177222222222223h a 755.4236111111111h): 288
#   - No recibieron noradrenalina durante la estancia:              2893

# %%
# Para los negativos que sí recibieron norad (pero tardíamente), ver cuándo la iniciaron
fig, ax = plt.subplots(figsize=(10, 5))
datos = neg_norad_tardia['horas_hasta_norad']
# Limitar el eje x por legibilidad (hay alguna estancia muy larga)
datos_mostrar = datos[datos <= 200]
ax.hist(datos_mostrar, bins=40, color='#1f77b4', alpha=0.7)
ax.axvline(24, color='red', linestyle='--', linewidth=2,
           label='Corte 24 h (límite de la ventana)')
ax.set_xlabel('Horas desde el ingreso en UCI hasta el inicio de noradrenalina')
ax.set_ylabel('Nº de estancias')
ax.set_title(f'Negativos con noradrenalina tardía')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Identificar pacientes que aparecen con etiqueta positiva en una estancia
por_paciente = df2.groupby('subject_id')['etiqueta_norad_6_24'].agg(['sum', 'count'])  #nos quedamos con los unos y ceros de cada "montón" y nos quedamos con la suma y counteo
pacientes_mixtos = por_paciente[(por_paciente['sum'] > 0) &
                                (por_paciente['sum'] < por_paciente['count'])] #al menios una estancia positiva y una negativa (suma tiene que dar uno y count 2 o más)

print(f"Pacientes con etiqueta mixta entre sus estancias: {len(pacientes_mixtos)}")
print(f"  (positivo en al menos una estancia, negativo en al menos otra)\n")

if len(pacientes_mixtos) > 0:
    print("Desglose:")
    print(pacientes_mixtos.head(10).to_string())
# Out:
# Pacientes con etiqueta mixta entre sus estancias: 10
#   (positivo en al menos una estancia, negativo en al menos otra)
#
# Desglose:
#             sum  count
# subject_id
# 10887818      1      2
# 11341217      1      2
# 13922987      1      2
# 14720260      1      2
# 14757759      1      2
# 14899107      1      2
# 16192841      1      2
# 16866064      1      2
# 19046107      1      2
# 19375822      1      2
